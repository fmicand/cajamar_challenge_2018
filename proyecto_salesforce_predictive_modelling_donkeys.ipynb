# %% [markdown]
# # Cajamar UniversityHack 2018 Datathon: Salesforce Predictive Modelling

# %% [markdown]
# #### Donkeys  | Universidad de Barcelona
#
# - Alex Escolá Nixon
# - Jaume Puigbó
# - Florent Micand

# %% [markdown]
# #### Agenda
# 1. Introducción
# 2. Análisis Exploratorio
# 3. Manipulación de variables
# 4. Modelo y ajuste de parámetros
# 5. Evaluación
# 6. Modelo final y generación de predicciones
# 7. Interpretabilidad y conclusiones

# %% [markdown]
# ### 1. Introducción

# %% [markdown]
# Se entiende por poder adquisitivo la capacidad de una persona por comprar bienes y servicios. Es crucial para una entidad financiera poder estimar el poder adquisitivo de sus clientes para ser capaz de ofrecerles los productos financieros más adecuados en su etapa como clientes de la entidad. Además, es una variable de gran utilidad para establecer el riesgo financiero asociado.
#
# En este proyecto presentamos un modelo predictivo que busca estimar de manera precisa el poder adquisitivo de cada cliente, a partir de un dataset con históricos de productos, consumos, saldos, número de operaciones y datos sociodemográficos de más de 300000 clientes. Se provee un fichero Train.txt para entrenar un modelo de aprendizaje automático de 363834 registros y 88 características, más la variable Poder Adquisitivo, que nos permitirá estimar el poder adquisitivo de los 156315 usuarios del fichero Test.txt.
#
# Este problema de Machine Learning posee algunas particularidades, para las cuales avanzamos algunas hipótesis a continuación. En primer lugar, la variable a estimar, el poder adquisitivo, no es una magnitud real que pueda ser observada, por la propia definición o naturaleza de la misma. Los valores de poder adquisitivo que aparecen en el dataset Train.txt han sido ellos mismos calculados o estimados por la entidad financiera, probablemente a partir de reglas, algoritmos y mayor cantidad de datos, en un amplio rango temporal, utilizando su know-how y experiencia en el sector.
#
# En segundo lugar, dado el orden de magnitud del poder adquisitivo y de otras variables numéricas, entendemos las características del dataset como la situación financiera en un preciso momento de los clientes, una foto instantánea, con algunos de los saldos, consumos, y número de operaciones agregados para un cierto periodo, por ejemplo mensualmente, trimestralmente o anualmente.
#
# Si la entidad financiera ya es capaz de establecer el poder adquisitivo con suficiente fiabilidad como para lanzar un reto nacional, ¿en qué medida podemos aportar valor presentando una solución a este reto? Pensamos que el valor radica en obtener el poder adquisitivo con las limitadas características de este dataset, marcadas por su restricción temporal. Ser capaz de establecer el poder adquisitivo de nuevos clientes, de los que se tengan pocos meses de información, para ofrecerles cuanto antes los productos financieros acordes con su poder adquisitivo, en cuanto a interés del cliente y riesgo financiero.
#
# Esta propuesta nos lleva a reflexionar sobre la evaluación más apropiada de la solución presentada a continuación. Aunque un error en términos absolutos o relativos es un buen indicador, y él que utilizaremos, podríamos aportar mayor valor de negocio conociendo umbrales de concesión de productos en término de poder adquisitivo, y así presentar un sistema de evaluación basado en probabilidad de idoneidad de producto según umbrales.
#
# Presentamos en primer lugar un análisis exploratorio de los datos, que justifican la manipulación de variables llevada a cabo, para después probar diferentes modelos predictivos. Tras comentar la bondad del modelo final mediante el sistema de evaluación elegido, generamos el fichero de entrega con las predicciones de poder adquisitivo para los clientes incluidos en Test.txt.

# %% [markdown]
# ### 2. Análisis Exploratorio

# %%
# %reset -f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.sparse as sp
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
import xgboost as xgb

# %%
path = "data/"
train_filename = "Dataset_Salesforce_Predictive_Modelling_TRAIN.txt"
df = pd.read_csv(path+train_filename,low_memory=False)

#Remplazamos un valor hexadecimal en la variable categórica Socio_Demo_01 por su correspondiente decimal
#para que no de problemas de tipo de datos luego.
df["Socio_Demo_01"].replace(to_replace='0X301', value=769, inplace=True)
df["Socio_Demo_01"] = df["Socio_Demo_01"].astype(np.float64)

# %% [markdown]
# #### 2.1 Poder adquisitivo

# %% [markdown]
# Empecemos por analizar los parámetros estadísticos y distribución del poder adquisitivo:

# %%
df['Poder_Adquisitivo'].describe()
# Out:
# count    3.638340e+05
# mean     1.642141e+04
# std      2.436773e+04
# min      3.600960e+03
# 25%      9.300933e+03
# 50%      1.292517e+04
# 75%      1.894854e+04
# max      5.040000e+06
# Name: Poder_Adquisitivo, dtype: float64

# %%
fig, ax =plt.subplots(1,1, figsize=(8,5))
facet =sns.boxplot(y="Poder_Adquisitivo", data=df, palette="RdBu_r", ax = ax)
facet.set(facecolor ="white")
plt.ylim(ymin=0,ymax=50000)
plt.show()

# %%
fig, ax =plt.subplots(1,1, figsize=(8,5))
sns.distplot(df['Poder_Adquisitivo'][df['Poder_Adquisitivo'] < 100000], ax = ax, bins = 120)
plt.xlim(xmax=50000)
plt.show()

# %% [markdown]
# Lo primero que podemos observar que la distribución tiene una larga cola derecha. Con lo que una buena opción, para quitar parte del peso que los outliers pueden suponer en el modelo, es transformar la variable dependiente mediante el logaritmo. De esta forma tendremos una distribución que se asemeja más a una distribución normal, por lo tanto más balanceada.
#
# Debido a que hay una cierta cantidad de datos mucho más elevados que los demás, hemos considerado que la solución que podria tener más lógica para este problema, desde el punto de vista entidad financiera, es la de tratar estos datos por separado. Además estos valores suponen un importante empeoramiento de los resultados del regresor utilizado.
#
# Teniendo ello en cuenta, hemos decidido prescindir de los clientes cuyo poder adquisitivo sea superior a aproximadamente los 200.000€, lo que supone quitar el percentil 0.1% de la parte superior de la distribución. Esto podría empeorar la predicción del modelo para clientes de poder adquisitivo muy alto, proponiendo por ejemplo valores cercanos a 200000€ y no a 1 millón. Este error no es relevante teniendo en cuenta que la entidad financiera seguramente provee una atención personalizada a clientes de muy alto poder adquisitivo a través de un asesor financiero.

# %%
fig, ax =plt.subplots(1,1, figsize=(8,5))
sns.distplot(np.log(df['Poder_Adquisitivo'][df['Poder_Adquisitivo'] < 100000]), ax = ax, bins = 120)
plt.show()

# %% [markdown]
# #### 2.2 Tenencia de los productos financieros </h3>

# %% [markdown]
# Realizamos un analisis exploratorio de las variables categoricas que indican la tenencia de los distintos productos financieros.
# Observamos las distribuciones de la cantidad de ceros, unos y doses que contienen cada una de la variables de Ind_Prod, las cuales indican respectivamente si no existe tenencia en los distintos productos financieros, si sí existe, o si ha existido en los últimos tres meses.

# %%
Ind_Prods = df.loc[:,'Ind_Prod_01':'Ind_Prod_24']
for col in Ind_Prods.columns:
    Ind_Prods.loc[:,col] = Ind_Prods.loc[:,col].astype(float)
    
fig, axes =plt.subplots(6,4, figsize=(13,13), sharex=True)
axes = axes.flatten()
for ax, catplot in zip(axes, Ind_Prods.columns):
    sns.countplot(y=catplot, data=Ind_Prods, ax=ax, 
                  order=np.unique(Ind_Prods.values), palette="husl")
    ax.set_xlabel('')
ax.set_xticklabels([])
plt.tight_layout()  
plt.show()

# %% [markdown]
# Por lo general, son pocos los casos en los que exista tenencia de productos financieros. La cantidad de doses en todos los casos es todavía más minoritaria. Teniendo en cuenta esta información, veamos más en detalle que utilidad pueden tener cada una de estas variables de cara a predecir el poder adquisitivo de un cliente.
#
# Para ello en la siguiente figura vemos para cada variable, la distribución del poder adquisitivo correspondiente a los clientes seccionados según los distintos valores que tóma cada Ind_Prod, es decir, 0,1 o 2.

# %%
fig, axes = plt.subplots(6,4, figsize=(13,13), sharex=False)
axes = axes.flatten()
for ax, catplot in zip(axes, Ind_Prods.columns):
    data_temp = pd.concat([df['Poder_Adquisitivo'], df[catplot]], axis=1)
    sns.boxplot(x=catplot, y="Poder_Adquisitivo", data=data_temp, ax=ax, palette="husl")
    ax.set_ylim(bottom=0,top=55000)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Si dejamos de lado por un momento los diagramas de cajas correspondientes a los doses de cada variable, vemos que las correspondientes distribuciones del poder adquisitivo varían bastante dependiendo de la tenencia de los distintos productos financieros. Ello nos está indicando por lo tanto que por lo general (exceptuando algunos casos como por ejemplo 'Ind_Prod_18'), dichas variables pueden resultar útiles para predecir el poder adquisitivo.
#
# También se observa que en la mayoría de casos la distribución del poder adquisitivo es parecida para los casos en los que sí se posee el producto financiero y para aquellos en los que la ha habido los últimos 3 meses. Por lo que, si añadimos el hecho de que la cantidad de doses es muy minoritaria, parece una buena opción tratar éstos dos útlimos como una sola variable.
#
# Por lo que a excepción de Ind_Prod_24, para la que sí se aprecia un importante augmento de media del poder adquisitivo en los clientes con un 2, los doses serán tratados como unos, de esta forma, debido a que las variables categóricas deben ser convertidas a OneHot, pasaríamos de tener tres columnas para cada variable (una para cada posible valor), a una sola.
#
# A continuación analicemos si existen correlaciones entre productos:

# %%
corr = Ind_Prods.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    fig, ax = plt.subplots(figsize = (15,15))
    sns.heatmap(corr, mask=mask, square=True, annot=False, cmap='Blues', ax=ax)
    plt.xticks(rotation=90, ha='center');
plt.show()

# %% [markdown]
# A primera vista las correlaciones cruzadas entre las variables son bajas. A excepción de alguna como es la correlación de 'Ind_Prod_08' con 'Ind_Prod_24', con una correlación del 89%:

# %%
np.corrcoef(Ind_Prods['Ind_Prod_24'],Ind_Prods['Ind_Prod_08'])
# Out:
# array([[ 1.        ,  0.89702905],
#        [ 0.89702905,  1.        ]])

# %% [markdown]
# No obstante si analizamos un poco más en detalle ambas variables, nos damos cuenta de que la correlacón se debe a que ambas variables contienen los ceros en las mismas posiciones.:

# %%
matches_of_zeros = len(np.intersect1d(list(np.where(Ind_Prods['Ind_Prod_24'] == 0)[0]), 
                             list(np.where(Ind_Prods['Ind_Prod_08'] == 0)[0])))
print 'Posiciones en que coinciden los ceros:', matches_of_zeros
print "Cantidad de ceros:", len(Ind_Prods[Ind_Prods['Ind_Prod_24'] == 0])
# Out:
# Posiciones en que coinciden los ceros: 68543
# Cantidad de ceros: 68543

# %% [markdown]
# Por lo que, teniendo en cuenta que 'Ind_Prod_24' contiene una gran cantidad de doses, y que la distribución del poder adquisitivo es más elevada para los usuarios con un dos como se ha argumentado previamente, ello nos indica que dicha información puede resultar valiosa de cara a la predicción. Por lo que podemos suponer que la variable 'Ind_Prod_08' no nos está aportando información disponiendo de 'Ind_Prod_24'.

# %% [markdown]
# También vemos una correlación significativa entre las variables 'Ind_Prod_14' y 'Ind_Prod_22'. En este caso se debe a que las posiciones contienen unos en las mismas posiciones. Pero los demás valores que contienen las categorías aportan información distinta por lo que no podemos realizar asunciones como con el caso previo.

# %% [markdown]
# Observando la gráfica de diagramas de caja de los valores categóricos vs el poder adquisitivo, vemos que 'Ind_Prod_18', además de contener unos casi en la totalidad de los casos, las distribuciones de los ceros y unos en dicha variable son muy parecidas. Por lo que cabe suponer que esta variable no aporta mucha información de cara a la predicción.

# %% [markdown]
# #### 2.3 Importe de los saldos de los distintos productos financieros </h3>

# %% [markdown]
# Para el análisis de dichas variables, empecemos por ver la cantidad de ceros que tiene cada una:

# %%
Imp_Sals = df.loc[:,'Imp_Sal_01':'Imp_Sal_21']
for i in Imp_Sals.columns:
    print i, 'contiene', len(df[i][df[i]!=0]), 'valores distintos a 0'
# Out:
# Imp_Sal_01 contiene 854 valores distintos a 0
# Imp_Sal_02 contiene 101501 valores distintos a 0
# Imp_Sal_03 contiene 952 valores distintos a 0
# Imp_Sal_04 contiene 43350 valores distintos a 0
# Imp_Sal_05 contiene 27163 valores distintos a 0
# Imp_Sal_06 contiene 7437 valores distintos a 0
# Imp_Sal_07 contiene 1615 valores distintos a 0
# Imp_Sal_08 contiene 358862 valores distintos a 0
# Imp_Sal_09 contiene 352781 valores distintos a 0
# Imp_Sal_10 contiene 295291 valores distintos a 0
# Imp_Sal_11 contiene 283 valores distintos a 0
# Imp_Sal_12 contiene 34383 valores distintos a 0
# Imp_Sal_13 contiene 10283 valores distintos a 0
# Imp_Sal_14 contiene 0 valores distintos a 0
# Imp_Sal_15 contiene 66000 valores distintos a 0
# Imp_Sal_16 contiene 175182 valores distintos a 0
# Imp_Sal_17 contiene 1156 valores distintos a 0
# Imp_Sal_18 contiene 3978 valores distintos a 0
# Imp_Sal_19 contiene 356416 valores distintos a 0
# Imp_Sal_20 contiene 177124 valores distintos a 0
# Imp_Sal_21 contiene 361409 valores distintos a 0

# %% [markdown]
# Vemos claramente, que muchas de ellas contienen muy poca información y no aportarían valor de cara a la regresión. Ello ha sido además corroborado con el análisis de la importancia de cada variable obtenido a partir del mismo regresor XGBoostRegressor con el que se ha realizado la predicción. No obstante, como comentamos, ello será corroborado con la importancia de las variables obtenidas con el mismo modelo, ya que, para algunos casos como es el de Imp_Sal_07, aun contener muy poca información sí resulta útil para el modelo.
# Por lo que dichas variables no serán utilizadas en el modelo.

# %%
to_drop = ['Imp_Sal_01', 'Imp_Sal_03', 'Imp_Sal_11', 'Imp_Sal_14', 'Imp_Sal_17']
low_values = ['Imp_Sal_06', 'Imp_Sal_07', 'Imp_Sal_12', 'Imp_Sal_13', 'Imp_Sal_18']
Imp_Sal_hist = pd.concat([Imp_Sals, df.loc[:,'Poder_Adquisitivo']], axis = 1)\
                        .drop(to_drop, axis = 1).drop(low_values, axis = 1)

# %% [markdown]
# A continuación veamos los histogramas de las siguientes variables:

# %%
fig, axes = plt.subplots(4,3, figsize=(10,10), sharex=False)
axes = axes.flatten()
for ax, catplot in zip(axes, Imp_Sal_hist.columns[:-1]):
    train_subplot = Imp_Sal_hist[Imp_Sal_hist[catplot] != 0]
    data_to_plot = train_subplot[catplot][train_subplot[catplot] < np.percentile(train_subplot[catplot], 90)]
    data_to_plot.hist(bins = 250, ax=ax)
    ax.set_title(catplot)
    ax.xaxis.set_ticks(np.arange(min(data_to_plot), max(data_to_plot)+1, (max(data_to_plot) - min(data_to_plot)+1)/5.))
    ax.set_xlim(xmin = data_to_plot.min(), xmax=np.percentile(data_to_plot, 90))
plt.tight_layout()  
plt.show()

# %% [markdown]
# Lo primero que observamos es la evidente asimetría estadística que poseen todas las variables. Vemos que el importe de los saldos de los distintos productos financieros son por lo general bajos, con una frecuencia menguante para importes más altos. Por lo que también podría plantearse la tranformación logarítmica de estas variables, con tal de quitar peso a la mayor variabilidad que tendrán los valores más elevados de éstas, para ver si benefician al modelo.

# %%
Log_Imp_Sal = [u'Imp_Sal_02', u'Imp_Sal_08',
       u'Imp_Sal_09', u'Imp_Sal_10', u'Imp_Sal_15', u'Imp_Sal_16',
       u'Imp_Sal_19', u'Imp_Sal_20', u'Imp_Sal_21']
def log_transform(df,col):
    return pd.DataFrame(np.log(df[col] + 1 + abs(min(df[col]))), columns = [col])

# %%
fig, axes = plt.subplots(3,3, figsize=(10,10), sharex=False)
axes = axes.flatten()
for ax, catplot in zip(axes, Log_Imp_Sal):
    train_subplot = Imp_Sal_hist.loc[Imp_Sal_hist[catplot] != 0]
    train_subplot.loc[:,catplot] = log_transform(train_subplot, catplot)
    train_subplot.loc[:,catplot].hist(bins = 250, ax=ax)
    ax.set_xlim(xmin = np.percentile(train_subplot[catplot], 2), xmax=np.percentile(train_subplot[catplot], 99.9))
    ax.set_title(catplot)
plt.tight_layout()  
plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %% [markdown]
# Vemos que de esta forma también resulta más fácil extraer información relevante de las distribibuciones al asemejarse más a distribuciones normales. Vemos por ejemplo que Imp_Sal_20 posee una distribución claramente bimodal:

# %%
fig, ax =plt.subplots(1,1, figsize=(8,5))
log_transform(df,'Imp_Sal_20').hist(bins = 400, ax=ax)
plt.xlim(xmin=4, xmax = 13)
plt.ylim(ymax = 3000)
plt.show()

# %% [markdown]
# Por lo que, teniendo en cuenta que ésta es una variable importante para el modelo como mostramos más adelante, una opción que hemos analizado es tratar ambas modas de dicha variable por separado, con lo que cada una se asemejaría más a una distribución normal. En este preciso caso no ha mejorado la predicción.
#
# Analicemos ahora algunas de las correlaciones existentes entre las variables de saldo más destacadas:

# %%
sns.set()
g = sns.pairplot(df[['Imp_Sal_08', 'Imp_Sal_09', 'Imp_Sal_19', 'Imp_Sal_21']], size = 3)
g.set(xticklabels=[], facecolor ="white")
plt.show();

# %% [markdown]
# Observamos que existe cierta relación entre las variables. Por ejemplo, el importe del salario del producto financiero 19 marca un cierto umbral inferior en el del 21. Sin embargo, la correlación entre ambas no es suficientemente alta como para no utilizar alguna de ellas.
#
# No obstante sí existe una alta correlación el 8 i el 9:

# %%
np.corrcoef(df.Imp_Sal_08,df.Imp_Sal_09)
# Out:
# array([[1.        , 0.87472757],
#        [0.87472757, 1.        ]])

# %% [markdown]
# Al estar correlacionadas casi al 90%, en este caso sí podriamos considerar el utilizar tan solo una de ellas para evitar que ello afecte al modelo, o dar demasiado peso a esta variable que, en cierto modo podemos considerar que aporta la misma información. Sin embargo la incidencia de tener variables correlacionadas es posteriormente analizada a partir de los resultados debido a que el XGBRegressor es robusto a correlaciones entre variables.
#
# Viendo más en detalle la distribución de ambas, vemos que son casi idénticas:

# %%
fig, ax = plt.subplots(figsize = (8,5))
for a in [log_transform(df,'Imp_Sal_08'), log_transform(df,'Imp_Sal_09')]:
    g = sns.distplot(a, bins=50, ax=ax, label=a.columns[0])
    g.set(facecolor = "white")
ax.set_xlim([2, 12])
ax.set_xlabel('')
plt.legend()
plt.show()

# %% [markdown]
# También analizando las correlaciones de las variables con el poder adquisitivo, hemos considerado interesante comentar el comportamiento de Imp_Sal_21. Como podemos observar en el siguiente diagrama de dispersión de dicha variable con el poder adquisitivo, vemos que el importe del salario del producto 21 marca un cierto umbral inferior de poder adquisitivo. Ello nos indica que dicha variable posiblemente sea útil de cara a predecir el poder adquisitivo, ya que para ciertos importes el poder adquisitivo, como se observa, no baja de cierto mínimo.

# %%
fig, ax = plt.subplots(figsize = (8,5))
g = df.plot.scatter(x='Imp_Sal_21', y='Poder_Adquisitivo', ax = ax)
g.set(facecolor = "white")
plt.xticks(np.arange(min(df.Imp_Sal_21), max(df.Imp_Sal_21)+1, (max(df.Imp_Sal_21)+1 - min(df.Imp_Sal_21))/5.))
plt.ylim(ymin=-50000)
plt.xlim(xmin=-50000)
plt.show()

# %% [markdown]
# #### 2.4 Importe de consumos habituales del cliente en base a sus operaciones con tarjetas y domiciliaciones más comunes </h3>

# %% [markdown]
# Veamos que distribuciones tienen estas variables:

# %%
Imp_Cons = df.loc[:,'Imp_Cons_01':'Imp_Cons_17']

fig, ax = plt.subplots(figsize = (15,8))
g = sns.boxplot(data=np.array(Imp_Cons), ax = ax)  
g.set(facecolor = "white")
ax.set(ylim=(-10, 600))
plt.xticks(np.arange(len(Imp_Cons.columns)), (Imp_Cons.columns), rotation = 90)
plt.tick_params(axis='both', which='major', labelsize=10)
plt.show()

# %% [markdown]
# Toman rangos de valores bastante distintos, con algunas de ellas muy concentradas en 0, debido a la gran cantidad de ceros que tienen algunas de ellas.
#
# Veamos las distribuciones de estas variables en forma de histogramas también, tomando la transformación logarítmica para una mejor observación de sus respectivas distribuciones:

# %%
fig, axes = plt.subplots(5,4, figsize=(13,13), sharex=False)
axes = axes.flatten()
for ax, catplot in zip(axes, Imp_Cons.columns):
    train_subplot = Imp_Cons[Imp_Cons[catplot] != 0]
    train_subplot.loc[:,catplot] = np.log(train_subplot[catplot] + 1 + abs(min(train_subplot[catplot])))
    g = train_subplot[catplot][train_subplot[catplot] < np.percentile(train_subplot[catplot], 99)].hist(bins = 150, ax=ax)
    g.set(facecolor = "white")
    ax.set_xlim(xmin = train_subplot[catplot].min(), xmax=np.percentile(train_subplot[catplot], 99))
    ax.set_title(catplot)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Veamos ahora si existen correlaciones destacables entre las variables:

# %%
corr = Imp_Cons.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    fig, ax = plt.subplots(figsize = (15,15))
    sns.heatmap(corr, mask=mask, square=True, annot=False, cmap='Blues', ax = ax)
    plt.xticks(rotation=90, ha='center');
plt.show()

# %% [markdown]
# En este caso vemos que existe muy poca correlación entre las variables.

# %% [markdown]
# #### 2.5 Datos socio-demográficos

# %% [markdown]
# Como viene especificado, Socio_Demo_01 es una variable categórica. Por lo que una opción es generar dummies con cada uno de los posible valores:

# %%
len(df.Socio_Demo_01.unique())
# Out:
# 509

# %% [markdown]
# Sin embargo ello sigue suponiendo generar más de 500 variables nuevas. Por lo que una opción es quedarse con la información más relevante mediante un bucketing de la variable.
#
# Para explicar mejor el proceso, veamos como depende el poder adquisitivo del cliente en función de dicha variable.

# %%
mean_adq_power = df.groupby('Socio_Demo_01').mean()['Poder_Adquisitivo']

# %%
fig, ax = plt.subplots(1,1, figsize = (8,5))
ax.set_facecolor('white')
g = plt.scatter(mean_adq_power.index,mean_adq_power.values)
plt.ylim(ymin=0,ymax=60000)
plt.xlim(xmin=0,xmax=10000)
plt.xlabel('Socio Demo 01 (rango numerico)')
plt.ylabel('Poder adquisitivo')
plt.show()

# %% [markdown]
# Vemos que existe una gran variabilidad en el poder adquisitivo en función del valor categórico que toma Socio_Demo_01.
# Por lo que para no desperdiciar información relevante que puede proporcionar esta variable, una opción es seleccionar las categorias de que toma dicha variable para las cuales el poder adquisitivo es más extremo.
#
# Para ello hemos creado dos variables nuevas, una en la cual hemos introducido unos si la categoría forma parte de las 100 categorías con mayor poder adquisitivo de media, y la otra variable equivalentemente pero para el menor poder adquisitivo.

# %%
def buckets(df):

    sumation_SD1 = df.Poder_Adquisitivo.groupby(df.Socio_Demo_01).sum()
    count_SD1 = df.Poder_Adquisitivo.groupby(df.Socio_Demo_01).count()
    avg_sum_SD1 = sumation_SD1/count_SD1

    temp = avg_sum_SD1.argsort().reset_index()
    bucket_1 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[-30:]
    bucket_2 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[-100:-30]
    bucket_3 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[:100]
    return bucket_1,bucket_2,bucket_3

bucket_1,bucket_2,bucket_3 = buckets(df)

# %%
mean_adq_power = df.groupby('Socio_Demo_01').mean()['Poder_Adquisitivo']
high = mean_adq_power[bucket_1]
medium_high = mean_adq_power[bucket_2]
low = mean_adq_power[bucket_3]
others = mean_adq_power[(~mean_adq_power.index.isin(bucket_1)) & (~mean_adq_power.index.isin(bucket_2))\
                       & (~mean_adq_power.index.isin(bucket_3))]

# %%
fig, ax = plt.subplots(1,1, figsize = (8,5))
ax.set_facecolor('white')

blue = plt.scatter(others.index,others.values, c='b')
yellow =  plt.scatter(medium_high.index,medium_high.values, c='y')
red = plt.scatter(high.index,high.values, c='r')
green = plt.scatter(low.index,low.values, c='g')
plt.legend((red,yellow,blue,green),
           ('High AP','Medium-High','Interm.', 'Low AP'))
plt.ylim(ymin=0,ymax=60000)
plt.xlim(xmin=0,xmax=10000)
plt.xlabel('Socio Demo 01 (rango numerico)')
plt.ylabel('Poder adquisitivo')
plt.show()

# %% [markdown]
# De esta forma evitamos generar una gran cantidad de variables nuevas y mantenemos cierta información que nos puede proporcionar esta variable.

# %% [markdown]
# #### 2.6 Número de operaciones a través de los distintos productos financieros </h3>

# %% [markdown]
# Empecemos por ver primero, la cantidad de entradas distintas a 0 que tienen estas variables:

# %%
Num_Opers = df.loc[:,'Num_Oper_01':'Num_Oper_20']

for i in df.loc[:,'Num_Oper_01':'Num_Oper_20'].columns:
    print i, 'has', len(df[i][df[i]!=0]), 'entries different than 0'
# Out:
# Num_Oper_01 has 87839 entries different than 0
# Num_Oper_02 has 62443 entries different than 0
# Num_Oper_03 has 169450 entries different than 0
# Num_Oper_04 has 1093 entries different than 0
# Num_Oper_05 has 353630 entries different than 0
# Num_Oper_06 has 345054 entries different than 0
# Num_Oper_07 has 35073 entries different than 0
# Num_Oper_08 has 55297 entries different than 0
# Num_Oper_09 has 146035 entries different than 0
# Num_Oper_10 has 145702 entries different than 0
# Num_Oper_11 has 452 entries different than 0
# Num_Oper_12 has 1042 entries different than 0
# Num_Oper_13 has 25705 entries different than 0
# Num_Oper_14 has 6098 entries different than 0
# Num_Oper_15 has 43246 entries different than 0
# Num_Oper_16 has 932 entries different than 0
# Num_Oper_17 has 295291 entries different than 0
# Num_Oper_18 has 77800 entries different than 0
# Num_Oper_19 has 191794 entries different than 0
# Num_Oper_20 has 1409 entries different than 0

# %% [markdown]
# Vemos que, del mismo modo que con el importe de los saldos de los productos, hay algunas con muy poca información, por lo que podemos prescindir de ellas.
#
# Veamos ahora las distribuciones de estas variables:

# %%
fig, axes = plt.subplots(5,4, figsize=(13,13), sharex=False)
axes = axes.flatten()
for ax, catplot in zip(axes, Num_Opers.columns):
    train_subplot = Num_Opers[Num_Opers[catplot] != 0]
    g = train_subplot[catplot][train_subplot[catplot] < np.percentile(train_subplot[catplot], 99)].hist(bins = 150, ax=ax)
    g.set(facecolor = "white")
    ax.set_xlim(xmin = train_subplot[catplot].min(), xmax=np.percentile(train_subplot[catplot], 99))
    ax.set_title(catplot)
plt.tight_layout()  
plt.show()

# %% [markdown]
# #### 2.7 Correlaciones con el poder adquisitivo </h3>

# %%
corr = df.corr()
k = 10 #number of variables for heatmap
cols = corr.nlargest(k, 'Poder_Adquisitivo')['Poder_Adquisitivo'].index
mask = np.zeros_like(df[list(cols.values)].corr())
mask[np.triu_indices_from(mask, k=1)] = True
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
with sns.axes_style("white"):
    fig, ax = plt.subplots(figsize = (13,13))
    hm = sns.heatmap(cm, mask=mask, annot=True, square=True, annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values,cmap='Blues')
    plt.show()

# %% [markdown]
# Esta matriz de correlación nos está dando una visión de qué variables están más correlacionadas con el poder adquisitivo. Vemos que, las variables que más correlación muestran con la variable dependiente son algunos de los importes de saldos de distintos productos. En especial el 8 y 9, los cuales no es de sorprender que tengan valores similares de correlación debido a que también están altamente correlacionados entre sí. Y vemos también que el número de operaciones 5 y 6 también muestran cierta correlación, por lo que presumiblemente también serán importantes para el modelo.

# %% [markdown]
# También hemos probamos de añadir nuevas variables cogiendo la suma, media, desviación estándar, etc de los grupos de las variables numéricas de Imp_Cons e Imp_Sal. Por otra parte, probamos de hacer un k-means de 10 y 11 clústers  de dichas variables respectivamente. Elejimos estas k's despúes de una evaluación de la curva Elbow.
#
# Finalmente, no usamos ninguna de estas variables ya que no ayudaban al modelo.

# %% [markdown]
# ### 3. Manipulación de variables

# %%
# %reset -f
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.sparse as sp
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
import pickle
import operator
import xgboost as xgb

# %%
path = "data/"
train_filename = "Dataset_Salesforce_Predictive_Modelling_TRAIN.txt"
df = pd.read_csv(path+train_filename,low_memory=False)

#Remplazamos un valor hexadecimal en la variable categórica Socio_Demo_01 por su correspondiente decimal
#para que no de problemas de tipo de datos luego.
df["Socio_Demo_01"].replace(to_replace='0X301', value=769, inplace=True)
df["Socio_Demo_01"] = df["Socio_Demo_01"].astype(np.float64)

# %% [markdown]
# A partir de los insights encontrados en el análisis exploratorio, aplicamos las siguientes manipulaciones de variables:
# - Drop de variables no relevantes para el modelo
# - Drop de usuarios cuyo poder adquisitivo es mayor que el percentil 99.9%
# - Conversión de "2" a "1" en productos (excepto producto 24)
# - Normalización de variables numéricas
# - OneHot Encoding de variables catégoricas no binarias
# - Conversión logarítmica del poder adquisitivo
# - Buckets para la variable Socio_Demo_01 en función de su relación con el poder adquisitivo
# - Creación de variables comentadas en la sección anterior

# %%
# NA
print df.shape
df = df.dropna().reset_index(drop = True)
print "Duplicated: "+str(np.any(df.duplicated().values))
print df.shape
# Out:
# (363834, 89)
# Duplicated: False
# (363224, 89)

# %%
# Outliers
print df.shape
df = df[df['Poder_Adquisitivo'] < np.percentile(df['Poder_Adquisitivo'], 99.9)]
print df.shape
# Out:
# (363224, 89)
# (362860, 89)

# %% [markdown]
# En un primer momento, realizamos un split temporal para calcular los buckets de la variable Socio_Demo_01 sobre el futuro conjunto de train unicamente; calculando estos buckets sin usar el futuro conjunto de test.

# %%
df_train_temp, df_test_temp, y_train_temp, y_test_temp = train_test_split(df, df["Poder_Adquisitivo"].values, random_state=44)

# %%
# Función auxiliar para generar buckets de Socio_Demo_01 usuada durante el análisis exploratorio
def buckets(df):

    sumation_SD1 = df.Poder_Adquisitivo.groupby(df.Socio_Demo_01).sum()
    count_SD1 = df.Poder_Adquisitivo.groupby(df.Socio_Demo_01).count()
    avg_sum_SD1 = sumation_SD1/count_SD1

    temp = avg_sum_SD1.argsort().reset_index()
    bucket_1 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[-30:]
    bucket_2 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[-100:-30]
    bucket_3 = temp.loc[temp.Poder_Adquisitivo,:].Socio_Demo_01.values[:100]
    bucket_others = np.setdiff1d(np.unique(df_train_temp["Socio_Demo_01"].values), np.append(np.append(bucket_1,bucket_2),bucket_3))
    return bucket_1,bucket_2,bucket_3,bucket_others

bucket_1,bucket_2,bucket_3,bucket_others = buckets(df_train_temp)

# %% [markdown]
# Reproducimos el split anterior con 2/3 para el conjunto de train y 1/3 para el conjunto de test, ya de manera definitiva, con el mismo random_state anterior.

# %%
#Labels con transformacion logaritmica
y = np.log(df["Poder_Adquisitivo"].values)
print(y.shape)

#Dataset principal sin labels
X = df.drop("Poder_Adquisitivo", axis = 1)
print(X.shape)

#Split 2/3 y 1/3
df_train, df_test, y_train, y_test = train_test_split(X, y, random_state=44)
# Out:
# (362860L,)
# (362860, 88)

# %% [markdown]
# Detallamos los grupos de variables que usaremos en el modelo.

# %%
categorical = np.array([u'Ind_Prod_01', u'Ind_Prod_02',
       u'Ind_Prod_03', u'Ind_Prod_04', u'Ind_Prod_05', u'Ind_Prod_06',
       u'Ind_Prod_07', u'Ind_Prod_08', u'Ind_Prod_09', u'Ind_Prod_10',
       u'Ind_Prod_11', u'Ind_Prod_12', u'Ind_Prod_13', u'Ind_Prod_14',
       u'Ind_Prod_15', u'Ind_Prod_16', u'Ind_Prod_17', u'Ind_Prod_18',
       u'Ind_Prod_19', u'Ind_Prod_20', u'Ind_Prod_21', u'Ind_Prod_22',
       u'Ind_Prod_23',"Socio_Demo_02"])

categorical_to_onehot = np.array(['Ind_Prod_24',"Socio_Demo_01"])

numerical = np.array([u'Imp_Cons_01', u'Imp_Cons_02', u'Imp_Cons_03',
       u'Imp_Cons_04', u'Imp_Cons_05', u'Imp_Cons_06', u'Imp_Cons_07',
       u'Imp_Cons_08', u'Imp_Cons_09', u'Imp_Cons_10', u'Imp_Cons_11',
       u'Imp_Cons_12', u'Imp_Cons_13', u'Imp_Cons_14', u'Imp_Cons_15',
       u'Imp_Cons_16', u'Imp_Cons_17', u'Imp_Sal_02',
       u'Imp_Sal_04', u'Imp_Sal_05', u'Imp_Sal_06',
       u'Imp_Sal_07', u'Imp_Sal_08', u'Imp_Sal_09', u'Imp_Sal_10',
       u'Imp_Sal_12', u'Imp_Sal_13', u'Imp_Sal_15',
       u'Imp_Sal_16', u'Imp_Sal_18', u'Imp_Sal_19',
       u'Imp_Sal_21', u'Num_Oper_01', u'Num_Oper_02',
       u'Num_Oper_03', u'Num_Oper_05', u'Num_Oper_06',
       u'Num_Oper_07', u'Num_Oper_08', u'Num_Oper_09', u'Num_Oper_10',
       u'Num_Oper_13', u'Num_Oper_14',
       u'Num_Oper_15', u'Num_Oper_17', u'Num_Oper_18',
       u'Num_Oper_19', u'Socio_Demo_03',
       u'Socio_Demo_04', u'Socio_Demo_05'])

# %% [markdown]
# Aplicamos las transformaciones mencionadas, sobre ambos conjuntos. La función siguiente devuelve matrices numpy en formato sparse, lo que incrementará la velocidad del modelo.

# %%
#Transformaciones
def transform(df,numerical,categorical,minmax,onehot,bucket_1,bucket_2,bucket_3,bucket_others, train = True):
    
    # Restamos 1 a la categórica socio_demo_02 para que tenga la forma 0,1 y no 1,2
    df.loc[:,"Socio_Demo_02"] = df.loc[:,"Socio_Demo_02"]-1
    
    # Remplazamos 2 por 1 en los productos con pocos 2
    for col in df.loc[:,'Ind_Prod_01':'Ind_Prod_23'].columns:
        df.loc[:,col] = df.loc[:,col].astype(int)
        df.loc[:,col].replace(to_replace=2, value=1, inplace=True)
    
    # Bucketing de Socio_Demo_01  
    df["Socio_Demo_01"].replace(to_replace = bucket_1, value = 1, inplace = True)
    df["Socio_Demo_01"].replace(to_replace = bucket_2, value = 2, inplace = True)
    df["Socio_Demo_01"].replace(to_replace = bucket_3, value = 3, inplace = True)
    df["Socio_Demo_01"].replace(to_replace = bucket_others, value = 0, inplace = True)
                            
    if train == True:
        #MinMax Scaling Fit de las features numéricas y OneHot Encoding Fit de las features 
        #a las que aplica, entrenadas en el conjunto de train unicamente
        minmax = MinMaxScaler()
        minmax.fit(df[numerical])

        onehot = OneHotEncoder()
        onehot.fit(df[categorical_to_onehot])
    
    #MinMax Scaling de las features numéricas y en sparse
    df_num_scaled = minmax.transform(df[numerical])
    df_num_sparse = sp.csr_matrix(df_num_scaled)  
    print "Features Numéricas: "+str(df_num_sparse.shape[1])
    
    # OneHot de features categoricas
    f_onehot_names = []
    for name in categorical_to_onehot:
        for i in range(len(df[name].unique())):
            aux = name + '_' + str(i)
            f_onehot_names.append(aux)
    df_cat_encoded = onehot.transform(df[categorical_to_onehot])
    print "Features Categóricas sin OneHot encoding: "+str(df[categorical].shape[1])
    print "Features Categóricas con OneHot encoding: "+str(df_cat_encoded.shape[1])
    
    # Concatenamos las matrices en formato sparse
    X = sp.hstack([df_num_sparse,sp.csr_matrix(df[categorical]),df_cat_encoded])
                                                         
    f_names = np.hstack([numerical,categorical,f_onehot_names])
    print "Dataset: "+str(X.shape)    
    return X, f_names, minmax, onehot

# %%
minmax = []
onehot = []
x_train, f_names, minmax1, onehot1 = transform(df_train,numerical,categorical,minmax,onehot,bucket_1,bucket_2,bucket_3,bucket_others)
x_test, trash1, trash2, trash3 = transform(df_test,numerical,categorical,minmax1,onehot1,bucket_1,bucket_2,bucket_3,bucket_others, train = False)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py:3813: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# Features Numéricas: 50
# Features Categóricas sin OneHot encoding: 24
# Features Categóricas con OneHot encoding: 7
# Dataset: (272145, 81)
# Features Numéricas: 50
# Features Categóricas sin OneHot encoding: 24
# Features Categóricas con OneHot encoding: 7
# Dataset: (90715, 81)

# %% [markdown]
# ### 4. Modelo y ajuste de parámetros

# %% [markdown]
# Este problema estándar de aprendize supervisado para obtener una regresión puede plantearse con distintos modelos muy conocidos, desde una simple regresión linear, que planteamos a continuación a modo de baseline, hasta aplicar Random Forest, XGBoost, o Redes Neuronales, entre otras opciones. Tras probar un modelo Random Forest y una red neuronal de varias capas densas, optamos por el Extreme Gradient Boosting Regressor o XGBoost, un modelo que ha destacado durante los últimos anos en competiciones Kaggle, y con él que hemos obtenido mejores resultados. XGBoost clasifica ejemplos mediante el uso de un conjunto de árboles de decisión. Los árboles se construyen secuencialmente, añadiendo en cada iteración el árbol que mejor compense por los errores de los árboles ya existentes. Se le llama método de gradiente porque el modelo evoluciona en dirección al menor error, árbol a árbol.

# %% [markdown]
# Aplicamos un sencillo modelo de regresión linear como baseline.

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
y_pred = LR.predict(x_test)

# Evaluacion: Mean Absolute Error
def mae(true, pred):
    y_diff = np.absolute(true - pred)
    print "MAE: " + str(np.mean(y_diff))
    
mae(np.exp(y_test), np.exp(y_pred))
# Out:
# MAE: 43829.3156074358

# %% [markdown]
# Se obtiene un error absoluto medio cercano a los 5600€, sabiendo que el promedio de poder adquisitivo es de 16000€ y la mediana de 13000€. Utilizamos esta regresión linear como característica de entrada al modelo XGBoost ya que mejorará su capacidad predictora.

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
lr_train = pd.DataFrame(data=LR.predict(x_train),columns = ["lr"])
lr_test = pd.DataFrame(data=LR.predict(x_test),columns = ["lr"])
print lr_train.shape
print lr_test.shape
x_train = sp.hstack([x_train,lr_train])
x_test = sp.hstack([x_test,lr_test])
# Out:
# (272145, 1)
# (90715, 1)

# %% [markdown]
# XGBoost posee varios hyperparámetros que deben ser tuneados para encontrar la combinación de aquellos que conducen al menor error absoluto medio: este proceso se denomina Grid Search. Lo ejecutamos a continuación, además de una validación cruzada (cross validation) para asegurarnos una correcta generalización del resultado. Además, utilizamos Early Stopping de Gradient Descent para evitar overfitting.
#
# En la celda siguiente lanzamos un Grid Search de ejemplo, ya con los mejores parámetros obtenidos en una ejecucción anterior, para que la presente ejecucción no tarde demasiado.

# %%
#Grid Search original
paramGrid = {'learning_rate': [0.01, 0.05, 0.1], 'max_depth': [15,20,25], 'min_child_weight':[3,5], 
          'gamma': [0.3,1,3], 'subsample':[0.75], 'colsample_bytree':[0.75], 
          'n_estimators': [2000]}

#Grid Search Best Parameters (Comentar la linea siguiente en caso de querer 
#ejecutar el Grid Search original)
paramGrid = {'learning_rate': [0.01], 'max_depth': [25], 'min_child_weight':[3], 
          'gamma': [0.3], 'subsample':[0.75], 'colsample_bytree':[0.75], 
          'n_estimators': [1000]}

fit_params={"early_stopping_rounds": 20, 
            "eval_metric" : "mae", 
            "eval_set" : [[x_test, y_test]]}

cv = 5
model = xgb.XGBRegressor(nthread=-1)
grid = GridSearchCV(model, paramGrid, scoring = 'neg_mean_absolute_error', verbose=3,
         fit_params=fit_params,
         cv=TimeSeriesSplit(n_splits=cv).get_n_splits([x_train,y_train]))
grid.fit(x_train,y_train)
print grid.best_params_
# Out:
# C:\Users\Jaume\Anaconda3\envs\old_python\lib\site-packages\sklearn\model_selection\_search.py:584: DeprecationWarning: "fit_params" as a constructor argument was deprecated in version 0.19 and will be removed in version 0.21. Pass fit parameters to the "fit" method instead.
#   '"fit" method instead.', DeprecationWarning)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] colsample_bytree=0.75, learning_rate=0.01, min_child_weight=3, n_estimators=1000, subsample=0.75, max_depth=25, gamma=0.3
# [0]	validation_0-mae:8.90392
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [1]	validation_0-mae:8.81491
# [2]	validation_0-mae:8.72677
# [3]	validation_0-mae:8.63953
# [4]	validation_0-mae:8.55315
# [5]	validation_0-mae:8.46762
# [6]	validation_0-mae:8.38296
# [7]	validation_0-mae:8.29915
# [8]	validation_0-mae:8.21617
# [9]	validation_0-mae:8.13405
# [10]	validation_0-mae:8.05273
# [11]	validation_0-mae:7.97222
# [12]	validation_0-mae:7.89253
# [13]	validation_0-mae:7.81363
# [14]	validation_0-mae:7.7355
# [15]	validation_0-mae:7.65818
# [16]	validation_0-mae:7.58161
# [17]	validation_0-mae:7.50581
# [18]	validation_0-mae:7.43077
# [19]	validation_0-mae:7.35648
# [20]	validation_0-mae:7.28294
# [21]	validation_0-mae:7.21012
# [22]	validation_0-mae:7.13804
# [23]	validation_0-mae:7.06667
# [24]	validation_0-mae:6.99603
# [25]	validation_0-mae:6.92609
# [26]	validation_0-mae:6.85685
# [27]	validation_0-mae:6.78831
# [28]	validation_0-mae:6.72045
# [29]	validation_0-mae:6.65327
# [30]	validation_0-mae:6.58675
# [31]	validation_0-mae:6.5209
# [32]	validation_0-mae:6.45571
# [33]	validation_0-mae:6.39117
# [34]	validation_0-mae:6.32726
# [35]	validation_0-mae:6.26401
# [36]	validation_0-mae:6.2014
# [37]	validation_0-mae:6.1394
# [38]	validation_0-mae:6.07803
# [39]	validation_0-mae:6.01726
# [40]	validation_0-mae:5.9571
# [41]	validation_0-mae:5.89755
# [42]	validation_0-mae:5.83859
# [43]	validation_0-mae:5.78023
# [44]	validation_0-mae:5.72244
# [45]	validation_0-mae:5.66524
# [46]	validation_0-mae:5.6086
# [47]	validation_0-mae:5.55253
# [48]	validation_0-mae:5.49702
# [49]	validation_0-mae:5.44208
# [50]	validation_0-mae:5.38767
# [51]	validation_0-mae:5.33382
# [52]	validation_0-mae:5.2805
# [53]	validation_0-mae:5.22772
# [54]	validation_0-mae:5.17546
# [55]	validation_0-mae:5.12372
# [56]	validation_0-mae:5.0725
# [57]	validation_0-mae:5.02179
# [58]	validation_0-mae:4.97159
# [59]	validation_0-mae:4.92189
# [60]	validation_0-mae:4.87269
# [61]	validation_0-mae:4.82399
# [62]	validation_0-mae:4.77578
# [63]	validation_0-mae:4.72804
# [64]	validation_0-mae:4.68078
# [65]	validation_0-mae:4.63399
# [66]	validation_0-mae:4.58767
# [67]	validation_0-mae:4.54182
# [68]	validation_0-mae:4.49642
# [69]	validation_0-mae:4.45148
# [70]	validation_0-mae:4.40699
# [71]	validation_0-mae:4.36294
# [72]	validation_0-mae:4.31933
# [73]	validation_0-mae:4.27616
# [74]	validation_0-mae:4.23341
# [75]	validation_0-mae:4.1911
# [76]	validation_0-mae:4.1492
# [77]	validation_0-mae:4.10773
# [78]	validation_0-mae:4.06667
# [79]	validation_0-mae:4.02602
# [80]	validation_0-mae:3.98579
# [81]	validation_0-mae:3.94595
# [82]	validation_0-mae:3.90651
# [83]	validation_0-mae:3.86746
# [84]	validation_0-mae:3.8288
# [85]	validation_0-mae:3.79053
# [86]	validation_0-mae:3.75264
# [87]	validation_0-mae:3.71513
# [88]	validation_0-mae:3.678
# [89]	validation_0-mae:3.64123
# [90]	validation_0-mae:3.60485
# [91]	validation_0-mae:3.56882
# [92]	validation_0-mae:3.53314
# [93]	validation_0-mae:3.49783
# [94]	validation_0-mae:3.46287
# [95]	validation_0-mae:3.42826
# [96]	validation_0-mae:3.39399
# [97]	validation_0-mae:3.36008
# [98]	validation_0-mae:3.32649
# [99]	validation_0-mae:3.29325
# [100]	validation_0-mae:3.26034
# [101]	validation_0-mae:3.22776
# [102]	validation_0-mae:3.19551
# [103]	validation_0-mae:3.16357
# [104]	validation_0-mae:3.13196
# [105]	validation_0-mae:3.10066
# [106]	validation_0-mae:3.06967
# [107]	validation_0-mae:3.03899
# [108]	validation_0-mae:3.00862
# [109]	validation_0-mae:2.97855
# [110]	validation_0-mae:2.94879
# [111]	validation_0-mae:2.91933
# [112]	validation_0-mae:2.89015
# [113]	validation_0-mae:2.86127
# [114]	validation_0-mae:2.83266
# [115]	validation_0-mae:2.80436
# [116]	validation_0-mae:2.77634
# [117]	validation_0-mae:2.7486
# [118]	validation_0-mae:2.72113
# [119]	validation_0-mae:2.69393
# [120]	validation_0-mae:2.66701
# [121]	validation_0-mae:2.64036
# [122]	validation_0-mae:2.61398
# [123]	validation_0-mae:2.58787
# [124]	validation_0-mae:2.56201
# [125]	validation_0-mae:2.53641
# [126]	validation_0-mae:2.51107
# [127]	validation_0-mae:2.48598
# [128]	validation_0-mae:2.46114
# [129]	validation_0-mae:2.43655
# [130]	validation_0-mae:2.4122
# [131]	validation_0-mae:2.38811
# [132]	validation_0-mae:2.36425
# [133]	validation_0-mae:2.34064
# [134]	validation_0-mae:2.31725
# [135]	validation_0-mae:2.29411
# [136]	validation_0-mae:2.27119
# [137]	validation_0-mae:2.2485
# [138]	validation_0-mae:2.22603
# [139]	validation_0-mae:2.20379
# [140]	validation_0-mae:2.18177
# [141]	validation_0-mae:2.15998
# [142]	validation_0-mae:2.13841
# [143]	validation_0-mae:2.11705
# [144]	validation_0-mae:2.09591
# [145]	validation_0-mae:2.07498
# [146]	validation_0-mae:2.05425
# [147]	validation_0-mae:2.03374
# [148]	validation_0-mae:2.01344
# [149]	validation_0-mae:1.99333
# [150]	validation_0-mae:1.97342
# [151]	validation_0-mae:1.95369
# [152]	validation_0-mae:1.93418
# [153]	validation_0-mae:1.91487
# [154]	validation_0-mae:1.89575
# [155]	validation_0-mae:1.87682
# [156]	validation_0-mae:1.85808
# [157]	validation_0-mae:1.83953
# [158]	validation_0-mae:1.82116
# [159]	validation_0-mae:1.80299
# [160]	validation_0-mae:1.78499
# [161]	validation_0-mae:1.76716
# [162]	validation_0-mae:1.74953
# [163]	validation_0-mae:1.73205
# [164]	validation_0-mae:1.71477
# [165]	validation_0-mae:1.69767
# [166]	validation_0-mae:1.68072
# [167]	validation_0-mae:1.66395
# [168]	validation_0-mae:1.64736
# [169]	validation_0-mae:1.63093
# [170]	validation_0-mae:1.61465
# [171]	validation_0-mae:1.59854
# [172]	validation_0-mae:1.5826
# [173]	validation_0-mae:1.56682
# [174]	validation_0-mae:1.5512
# [175]	validation_0-mae:1.53574
# [176]	validation_0-mae:1.52044
# [177]	validation_0-mae:1.5053
# [178]	validation_0-mae:1.49028
# [179]	validation_0-mae:1.47544
# [180]	validation_0-mae:1.46075
# [181]	validation_0-mae:1.44619
# [182]	validation_0-mae:1.43179
# [183]	validation_0-mae:1.41752
# [184]	validation_0-mae:1.40341
# [185]	validation_0-mae:1.38943
# [186]	validation_0-mae:1.37559
# [187]	validation_0-mae:1.36189
# [188]	validation_0-mae:1.34834
# [189]	validation_0-mae:1.33492
# [190]	validation_0-mae:1.32167
# [191]	validation_0-mae:1.30854
# [192]	validation_0-mae:1.29554
# [193]	validation_0-mae:1.28266
# [194]	validation_0-mae:1.26993
# [195]	validation_0-mae:1.25732
# [196]	validation_0-mae:1.24484
# [197]	validation_0-mae:1.23248
# [198]	validation_0-mae:1.22025
# [199]	validation_0-mae:1.20814
# [200]	validation_0-mae:1.19619
# [201]	validation_0-mae:1.18433
# [202]	validation_0-mae:1.1726
# [203]	validation_0-mae:1.161
# [204]	validation_0-mae:1.14951
# [205]	validation_0-mae:1.13816
# [206]	validation_0-mae:1.12692
# [207]	validation_0-mae:1.11576
# [208]	validation_0-mae:1.10473
# [209]	validation_0-mae:1.09383
# [210]	validation_0-mae:1.08303
# [211]	validation_0-mae:1.07237
# [212]	validation_0-mae:1.06181
# [213]	validation_0-mae:1.05138
# [214]	validation_0-mae:1.04102
# [215]	validation_0-mae:1.03081
# [216]	validation_0-mae:1.02071
# [217]	validation_0-mae:1.0107
# [218]	validation_0-mae:1.0008
# [219]	validation_0-mae:0.991
# [220]	validation_0-mae:0.981316
# [221]	validation_0-mae:0.97173
# [222]	validation_0-mae:0.962243
# [223]	validation_0-mae:0.952867
# [224]	validation_0-mae:0.943587
# [225]	validation_0-mae:0.934426
# [226]	validation_0-mae:0.925343
# [227]	validation_0-mae:0.916381
# [228]	validation_0-mae:0.907507
# [229]	validation_0-mae:0.898729
# [230]	validation_0-mae:0.890029
# [231]	validation_0-mae:0.881423
# [232]	validation_0-mae:0.872921
# [233]	validation_0-mae:0.864518
# [234]	validation_0-mae:0.856216
# [235]	validation_0-mae:0.848001
# [236]	validation_0-mae:0.839877
# [237]	validation_0-mae:0.831846
# [238]	validation_0-mae:0.823878
# [239]	validation_0-mae:0.816017
# [240]	validation_0-mae:0.808246
# [241]	validation_0-mae:0.800561
# [242]	validation_0-mae:0.792991
# [243]	validation_0-mae:0.785502
# [244]	validation_0-mae:0.778072
# [245]	validation_0-mae:0.770734
# [246]	validation_0-mae:0.763476
# [247]	validation_0-mae:0.756279
# [248]	validation_0-mae:0.749201
# [249]	validation_0-mae:0.742184
# [250]	validation_0-mae:0.735252
# [251]	validation_0-mae:0.72839
# [252]	validation_0-mae:0.721621
# [253]	validation_0-mae:0.714927
# [254]	validation_0-mae:0.708309
# [255]	validation_0-mae:0.701763
# [256]	validation_0-mae:0.695309
# [257]	validation_0-mae:0.68891
# [258]	validation_0-mae:0.68258
# [259]	validation_0-mae:0.67633
# [260]	validation_0-mae:0.670172
# [261]	validation_0-mae:0.664077
# [262]	validation_0-mae:0.658066
# [263]	validation_0-mae:0.652097
# [264]	validation_0-mae:0.646209
# [265]	validation_0-mae:0.640397
# [266]	validation_0-mae:0.634643
# [267]	validation_0-mae:0.628949
# [268]	validation_0-mae:0.62332
# [269]	validation_0-mae:0.61777
# [270]	validation_0-mae:0.612299
# [271]	validation_0-mae:0.606894
# [272]	validation_0-mae:0.601565
# [273]	validation_0-mae:0.596273
# [274]	validation_0-mae:0.59108
# [275]	validation_0-mae:0.585924
# [276]	validation_0-mae:0.580831
# [277]	validation_0-mae:0.575797
# [278]	validation_0-mae:0.570818
# [279]	validation_0-mae:0.565925
# [280]	validation_0-mae:0.561075
# [281]	validation_0-mae:0.556299
# [282]	validation_0-mae:0.551571
# [283]	validation_0-mae:0.546892
# [284]	validation_0-mae:0.542272
# [285]	validation_0-mae:0.537716
# [286]	validation_0-mae:0.533217
# [287]	validation_0-mae:0.528781
# [288]	validation_0-mae:0.524404
# [289]	validation_0-mae:0.520079
# [290]	validation_0-mae:0.515794
# [291]	validation_0-mae:0.511567
# [292]	validation_0-mae:0.507397
# [293]	validation_0-mae:0.503279
# [294]	validation_0-mae:0.499208
# [295]	validation_0-mae:0.495176
# [296]	validation_0-mae:0.491206
# [297]	validation_0-mae:0.487295
# [298]	validation_0-mae:0.483441
# [299]	validation_0-mae:0.479632
# [300]	validation_0-mae:0.475867
# [301]	validation_0-mae:0.472154
# [302]	validation_0-mae:0.468482
# [303]	validation_0-mae:0.464866
# [304]	validation_0-mae:0.461287
# [305]	validation_0-mae:0.457755
# [306]	validation_0-mae:0.454275
# [307]	validation_0-mae:0.450843
# [308]	validation_0-mae:0.44746
# [309]	validation_0-mae:0.444118
# [310]	validation_0-mae:0.44081
# [311]	validation_0-mae:0.437534
# [312]	validation_0-mae:0.434324
# [313]	validation_0-mae:0.431154
# [314]	validation_0-mae:0.428016
# [315]	validation_0-mae:0.424937
# [316]	validation_0-mae:0.421879
# [317]	validation_0-mae:0.418883
# [318]	validation_0-mae:0.415926
# [319]	validation_0-mae:0.413013
# [320]	validation_0-mae:0.410129
# [321]	validation_0-mae:0.407295
# [322]	validation_0-mae:0.404481
# [323]	validation_0-mae:0.401722
# [324]	validation_0-mae:0.398991
# [325]	validation_0-mae:0.396304
# [326]	validation_0-mae:0.393653
# [327]	validation_0-mae:0.391036
# [328]	validation_0-mae:0.388436
# [329]	validation_0-mae:0.385902
# [330]	validation_0-mae:0.383396
# [331]	validation_0-mae:0.380925
# [332]	validation_0-mae:0.378498
# [333]	validation_0-mae:0.376097
# [334]	validation_0-mae:0.373736
# [335]	validation_0-mae:0.371383
# [336]	validation_0-mae:0.369082
# [337]	validation_0-mae:0.366811
# [338]	validation_0-mae:0.364576
# [339]	validation_0-mae:0.362378
# [340]	validation_0-mae:0.360204
# [341]	validation_0-mae:0.358057
# [342]	validation_0-mae:0.355948
# [343]	validation_0-mae:0.353872
# [344]	validation_0-mae:0.351824
# [345]	validation_0-mae:0.349804
# [346]	validation_0-mae:0.347814
# [347]	validation_0-mae:0.34585
# [348]	validation_0-mae:0.343917
# [349]	validation_0-mae:0.342007
# [350]	validation_0-mae:0.34013
# [351]	validation_0-mae:0.338281
# [352]	validation_0-mae:0.336448
# [353]	validation_0-mae:0.334642
# [354]	validation_0-mae:0.332869
# [355]	validation_0-mae:0.331123
# [356]	validation_0-mae:0.329412
# [357]	validation_0-mae:0.32772
# [358]	validation_0-mae:0.326042
# [359]	validation_0-mae:0.324393
# [360]	validation_0-mae:0.322775
# [361]	validation_0-mae:0.321179
# [362]	validation_0-mae:0.319608
# [363]	validation_0-mae:0.31806
# [364]	validation_0-mae:0.316535
# [365]	validation_0-mae:0.315037
# [366]	validation_0-mae:0.313557
# [367]	validation_0-mae:0.3121
# [368]	validation_0-mae:0.310663
# [369]	validation_0-mae:0.309253
# [370]	validation_0-mae:0.307857
# [371]	validation_0-mae:0.306483
# [372]	validation_0-mae:0.305132
# [373]	validation_0-mae:0.303812
# [374]	validation_0-mae:0.302505
# [375]	validation_0-mae:0.301218
# [376]	validation_0-mae:0.299945
# [377]	validation_0-mae:0.298693
# [378]	validation_0-mae:0.297465
# [379]	validation_0-mae:0.296245
# [380]	validation_0-mae:0.295058
# [381]	validation_0-mae:0.29388
# [382]	validation_0-mae:0.292724
# [383]	validation_0-mae:0.291593
# [384]	validation_0-mae:0.290466
# [385]	validation_0-mae:0.289368
# [386]	validation_0-mae:0.288283
# [387]	validation_0-mae:0.287213
# [388]	validation_0-mae:0.286151
# [389]	validation_0-mae:0.285121
# [390]	validation_0-mae:0.284103
# [391]	validation_0-mae:0.283098
# [392]	validation_0-mae:0.282116
# [393]	validation_0-mae:0.281144
# [394]	validation_0-mae:0.280184
# [395]	validation_0-mae:0.279242
# [396]	validation_0-mae:0.278319
# [397]	validation_0-mae:0.277405
# [398]	validation_0-mae:0.276498
# [399]	validation_0-mae:0.275607
# [400]	validation_0-mae:0.274741
# [401]	validation_0-mae:0.273885
# [402]	validation_0-mae:0.273043
# [403]	validation_0-mae:0.272211
# [404]	validation_0-mae:0.271399
# [405]	validation_0-mae:0.270597
# [406]	validation_0-mae:0.269813
# [407]	validation_0-mae:0.26904
# [408]	validation_0-mae:0.268276
# [409]	validation_0-mae:0.267525
# [410]	validation_0-mae:0.266786
# [411]	validation_0-mae:0.266058
# [412]	validation_0-mae:0.265345
# [413]	validation_0-mae:0.264645
# [414]	validation_0-mae:0.263948
# [415]	validation_0-mae:0.26327
# [416]	validation_0-mae:0.262607
# [417]	validation_0-mae:0.261944
# [418]	validation_0-mae:0.261287
# [419]	validation_0-mae:0.260645
# [420]	validation_0-mae:0.260012
# [421]	validation_0-mae:0.259393
# [422]	validation_0-mae:0.258784
# [423]	validation_0-mae:0.25819
# [424]	validation_0-mae:0.257604
# [425]	validation_0-mae:0.257026
# [426]	validation_0-mae:0.256458
# [427]	validation_0-mae:0.255907
# [428]	validation_0-mae:0.255349
# [429]	validation_0-mae:0.254814
# [430]	validation_0-mae:0.25429
# [431]	validation_0-mae:0.253759
# [432]	validation_0-mae:0.253249
# [433]	validation_0-mae:0.252742
# [434]	validation_0-mae:0.252246
# [435]	validation_0-mae:0.251758
# [436]	validation_0-mae:0.251284
# [437]	validation_0-mae:0.250817
# [438]	validation_0-mae:0.250353
# [439]	validation_0-mae:0.249902
# [440]	validation_0-mae:0.249454
# [441]	validation_0-mae:0.249011
# [442]	validation_0-mae:0.24858
# [443]	validation_0-mae:0.248146
# [444]	validation_0-mae:0.247729
# [445]	validation_0-mae:0.247323
# [446]	validation_0-mae:0.246925
# [447]	validation_0-mae:0.246524
# [448]	validation_0-mae:0.24614
# [449]	validation_0-mae:0.245752
# [450]	validation_0-mae:0.245377
# [451]	validation_0-mae:0.244993
# [452]	validation_0-mae:0.244631
# [453]	validation_0-mae:0.24428
# [454]	validation_0-mae:0.243921
# [455]	validation_0-mae:0.243569
# [456]	validation_0-mae:0.243225
# [457]	validation_0-mae:0.24289
# [458]	validation_0-mae:0.242558
# [459]	validation_0-mae:0.24223
# [460]	validation_0-mae:0.24192
# [461]	validation_0-mae:0.241606
# [462]	validation_0-mae:0.241296
# [463]	validation_0-mae:0.240984
# [464]	validation_0-mae:0.240682
# [465]	validation_0-mae:0.240386
# [466]	validation_0-mae:0.240096
# [467]	validation_0-mae:0.239823
# [468]	validation_0-mae:0.239549
# [469]	validation_0-mae:0.239281
# [470]	validation_0-mae:0.239011
# [471]	validation_0-mae:0.238746
# [472]	validation_0-mae:0.238489
# [473]	validation_0-mae:0.238233
# [474]	validation_0-mae:0.237975
# [475]	validation_0-mae:0.23773
# [476]	validation_0-mae:0.237489
# [477]	validation_0-mae:0.237252
# [478]	validation_0-mae:0.237018
# [479]	validation_0-mae:0.236793
# [480]	validation_0-mae:0.236564
# [481]	validation_0-mae:0.23635
# [482]	validation_0-mae:0.23613
# [483]	validation_0-mae:0.235912
# [484]	validation_0-mae:0.235697
# [485]	validation_0-mae:0.235488
# [486]	validation_0-mae:0.235276
# [487]	validation_0-mae:0.235077
# [488]	validation_0-mae:0.234882
# [489]	validation_0-mae:0.234687
# [490]	validation_0-mae:0.234502
# [491]	validation_0-mae:0.234311
# [492]	validation_0-mae:0.234124
# [493]	validation_0-mae:0.23394
# [494]	validation_0-mae:0.233759
# [495]	validation_0-mae:0.233585
# [496]	validation_0-mae:0.233414
# [497]	validation_0-mae:0.233249
# [498]	validation_0-mae:0.233086
# [499]	validation_0-mae:0.232922
# [500]	validation_0-mae:0.232753
# [501]	validation_0-mae:0.232582
# [502]	validation_0-mae:0.232429
# [503]	validation_0-mae:0.232278
# [504]	validation_0-mae:0.232124
# [505]	validation_0-mae:0.231981
# [506]	validation_0-mae:0.23184
# [507]	validation_0-mae:0.231695
# [508]	validation_0-mae:0.231555
# [509]	validation_0-mae:0.231421
# [510]	validation_0-mae:0.231274
# [511]	validation_0-mae:0.231145
# [512]	validation_0-mae:0.231008
# [513]	validation_0-mae:0.230884
# [514]	validation_0-mae:0.230756
# [515]	validation_0-mae:0.230637
# [516]	validation_0-mae:0.230516
# [517]	validation_0-mae:0.230402
# [518]	validation_0-mae:0.230282
# [519]	validation_0-mae:0.230167
# [520]	validation_0-mae:0.230053
# [521]	validation_0-mae:0.229942
# [522]	validation_0-mae:0.229837
# [523]	validation_0-mae:0.229724
# [524]	validation_0-mae:0.229621
# [525]	validation_0-mae:0.22952
# [526]	validation_0-mae:0.229418
# [527]	validation_0-mae:0.229324
# [528]	validation_0-mae:0.22922
# [529]	validation_0-mae:0.229129
# [530]	validation_0-mae:0.229033
# [531]	validation_0-mae:0.228936
# [532]	validation_0-mae:0.228837
# [533]	validation_0-mae:0.228742
# [534]	validation_0-mae:0.228651
# [535]	validation_0-mae:0.228566
# [536]	validation_0-mae:0.228477
# [537]	validation_0-mae:0.228394
# [538]	validation_0-mae:0.22831
# [539]	validation_0-mae:0.228232
# [540]	validation_0-mae:0.228153
# [541]	validation_0-mae:0.228075
# [542]	validation_0-mae:0.227989
# [543]	validation_0-mae:0.227908
# [544]	validation_0-mae:0.227833
# [545]	validation_0-mae:0.227756
# [546]	validation_0-mae:0.227685
# [547]	validation_0-mae:0.22761
# [548]	validation_0-mae:0.227536
# [549]	validation_0-mae:0.227469
# [550]	validation_0-mae:0.227402
# [551]	validation_0-mae:0.227336
# [552]	validation_0-mae:0.227271
# [553]	validation_0-mae:0.227197
# [554]	validation_0-mae:0.227129
# [555]	validation_0-mae:0.227071
# [556]	validation_0-mae:0.227016
# [557]	validation_0-mae:0.226959
# [558]	validation_0-mae:0.226899
# [559]	validation_0-mae:0.22684
# [560]	validation_0-mae:0.226784
# [561]	validation_0-mae:0.226731
# [562]	validation_0-mae:0.226676
# [563]	validation_0-mae:0.226613
# [564]	validation_0-mae:0.226559
# [565]	validation_0-mae:0.226498
# [566]	validation_0-mae:0.226445
# [567]	validation_0-mae:0.226395
# [568]	validation_0-mae:0.22634
# [569]	validation_0-mae:0.22629
# [570]	validation_0-mae:0.226238
# [571]	validation_0-mae:0.226192
# [572]	validation_0-mae:0.226145
# [573]	validation_0-mae:0.226104
# [574]	validation_0-mae:0.226059
# [575]	validation_0-mae:0.226015
# [576]	validation_0-mae:0.225972
# [577]	validation_0-mae:0.225928
# [578]	validation_0-mae:0.225889
# [579]	validation_0-mae:0.225851
# [580]	validation_0-mae:0.225805
# [581]	validation_0-mae:0.225761
# [582]	validation_0-mae:0.225725
# [583]	validation_0-mae:0.225685
# [584]	validation_0-mae:0.225647
# [585]	validation_0-mae:0.225607
# [586]	validation_0-mae:0.225575
# [587]	validation_0-mae:0.225538
# [588]	validation_0-mae:0.225504
# [589]	validation_0-mae:0.225469
# [590]	validation_0-mae:0.225434
# [591]	validation_0-mae:0.225402
# [592]	validation_0-mae:0.22537
# [593]	validation_0-mae:0.225335
# [594]	validation_0-mae:0.225295
# [595]	validation_0-mae:0.22526
# [596]	validation_0-mae:0.225231
# [597]	validation_0-mae:0.225201
# [598]	validation_0-mae:0.225171
# [599]	validation_0-mae:0.225144
# [600]	validation_0-mae:0.225114
# [601]	validation_0-mae:0.225083
# [602]	validation_0-mae:0.225055
# [603]	validation_0-mae:0.225026
# [604]	validation_0-mae:0.224993
# [605]	validation_0-mae:0.224966
# [606]	validation_0-mae:0.224936
# [607]	validation_0-mae:0.224912
# [608]	validation_0-mae:0.224883
# [609]	validation_0-mae:0.224854
# [610]	validation_0-mae:0.224829
# [611]	validation_0-mae:0.224804
# [612]	validation_0-mae:0.224773
# [613]	validation_0-mae:0.224749
# [614]	validation_0-mae:0.224722
# [615]	validation_0-mae:0.224699
# [616]	validation_0-mae:0.224677
# [617]	validation_0-mae:0.224652
# [618]	validation_0-mae:0.224632
# [619]	validation_0-mae:0.224608
# [620]	validation_0-mae:0.224584
# [621]	validation_0-mae:0.224561
# [622]	validation_0-mae:0.224541
# [623]	validation_0-mae:0.224522
# [624]	validation_0-mae:0.2245
# [625]	validation_0-mae:0.224477
# [626]	validation_0-mae:0.224457
# [627]	validation_0-mae:0.22444
# [628]	validation_0-mae:0.22442
# [629]	validation_0-mae:0.224405
# [630]	validation_0-mae:0.224383
# [631]	validation_0-mae:0.224366
# [632]	validation_0-mae:0.224348
# [633]	validation_0-mae:0.224332
# [634]	validation_0-mae:0.224315
# [635]	validation_0-mae:0.224298
# [636]	validation_0-mae:0.224281
# [637]	validation_0-mae:0.224267
# [638]	validation_0-mae:0.224252
# [639]	validation_0-mae:0.224233
# [640]	validation_0-mae:0.224216
# [641]	validation_0-mae:0.224202
# [642]	validation_0-mae:0.224184
# [643]	validation_0-mae:0.22417
# [644]	validation_0-mae:0.224154
# [645]	validation_0-mae:0.224141
# [646]	validation_0-mae:0.224125
# [647]	validation_0-mae:0.224115
# [648]	validation_0-mae:0.224102
# [649]	validation_0-mae:0.224082
# [650]	validation_0-mae:0.224069
# [651]	validation_0-mae:0.224055
# [652]	validation_0-mae:0.224041
# [653]	validation_0-mae:0.224025
# [654]	validation_0-mae:0.224013
# [655]	validation_0-mae:0.224004
# [656]	validation_0-mae:0.223988
# [657]	validation_0-mae:0.223976
# [658]	validation_0-mae:0.223965
# [659]	validation_0-mae:0.223957
# [660]	validation_0-mae:0.223941
# [661]	validation_0-mae:0.223929
# [662]	validation_0-mae:0.223918
# [663]	validation_0-mae:0.223905
# [664]	validation_0-mae:0.223895
# [665]	validation_0-mae:0.223883
# [666]	validation_0-mae:0.223871
# [667]	validation_0-mae:0.223862
# [668]	validation_0-mae:0.223852
# [669]	validation_0-mae:0.22384
# [670]	validation_0-mae:0.223824
# [671]	validation_0-mae:0.223807
# [672]	validation_0-mae:0.223797
# [673]	validation_0-mae:0.223789
# [674]	validation_0-mae:0.22378
# [675]	validation_0-mae:0.223773
# [676]	validation_0-mae:0.223766
# [677]	validation_0-mae:0.223757
# [678]	validation_0-mae:0.223746
# [679]	validation_0-mae:0.223731
# [680]	validation_0-mae:0.223725
# [681]	validation_0-mae:0.223717
# [682]	validation_0-mae:0.223707
# [683]	validation_0-mae:0.223698
# [684]	validation_0-mae:0.223687
# [685]	validation_0-mae:0.223679
# [686]	validation_0-mae:0.223666
# [687]	validation_0-mae:0.223658
# [688]	validation_0-mae:0.223648
# [689]	validation_0-mae:0.223632
# [690]	validation_0-mae:0.223621
# [691]	validation_0-mae:0.223613
# [692]	validation_0-mae:0.223606
# [693]	validation_0-mae:0.2236
# [694]	validation_0-mae:0.223593
# [695]	validation_0-mae:0.223585
# [696]	validation_0-mae:0.223575
# [697]	validation_0-mae:0.223569
# [698]	validation_0-mae:0.223562
# [699]	validation_0-mae:0.223554
# [700]	validation_0-mae:0.223546
# [701]	validation_0-mae:0.223539
# [702]	validation_0-mae:0.223534
# [703]	validation_0-mae:0.223525
# [704]	validation_0-mae:0.223517
# [705]	validation_0-mae:0.223509
# [706]	validation_0-mae:0.2235
# [707]	validation_0-mae:0.223493
# [708]	validation_0-mae:0.223488
# [709]	validation_0-mae:0.223483
# [710]	validation_0-mae:0.223479
# [711]	validation_0-mae:0.223473
# [712]	validation_0-mae:0.223468
# [713]	validation_0-mae:0.223462
# [714]	validation_0-mae:0.223457
# [715]	validation_0-mae:0.223449
# [716]	validation_0-mae:0.223443
# [717]	validation_0-mae:0.223439
# [718]	validation_0-mae:0.223433
# [719]	validation_0-mae:0.223427
# [720]	validation_0-mae:0.223414
# [721]	validation_0-mae:0.223409
# [722]	validation_0-mae:0.223404
# [723]	validation_0-mae:0.223399
# [724]	validation_0-mae:0.223391
# [725]	validation_0-mae:0.223386
# [726]	validation_0-mae:0.22338
# [727]	validation_0-mae:0.223372
# [728]	validation_0-mae:0.223367
# [729]	validation_0-mae:0.223363
# [730]	validation_0-mae:0.223358
# [731]	validation_0-mae:0.223356
# [732]	validation_0-mae:0.223351
# [733]	validation_0-mae:0.223346
# [734]	validation_0-mae:0.223342
# [735]	validation_0-mae:0.223338
# [736]	validation_0-mae:0.223333
# [737]	validation_0-mae:0.223327
# [738]	validation_0-mae:0.223324
# [739]	validation_0-mae:0.22332
# [740]	validation_0-mae:0.223316
# [741]	validation_0-mae:0.22331
# [742]	validation_0-mae:0.223306
# [743]	validation_0-mae:0.223297
# [744]	validation_0-mae:0.223294
# [745]	validation_0-mae:0.223287
# [746]	validation_0-mae:0.223284
# [747]	validation_0-mae:0.223281
# [748]	validation_0-mae:0.223279
# [749]	validation_0-mae:0.223274
# [750]	validation_0-mae:0.22327
# [751]	validation_0-mae:0.223268
# [752]	validation_0-mae:0.223261
# [753]	validation_0-mae:0.223256
# [754]	validation_0-mae:0.223252
# [755]	validation_0-mae:0.22325
# [756]	validation_0-mae:0.223246
# [757]	validation_0-mae:0.223241
# [758]	validation_0-mae:0.223236
# [759]	validation_0-mae:0.223232
# [760]	validation_0-mae:0.223229
# [761]	validation_0-mae:0.223224
# [762]	validation_0-mae:0.223221
# [763]	validation_0-mae:0.223214
# [764]	validation_0-mae:0.22321
# [765]	validation_0-mae:0.223208
# [766]	validation_0-mae:0.223204
# [767]	validation_0-mae:0.223198
# [768]	validation_0-mae:0.223194
# [769]	validation_0-mae:0.22319
# [770]	validation_0-mae:0.223184
# [771]	validation_0-mae:0.22318
# [772]	validation_0-mae:0.223175
# [773]	validation_0-mae:0.223171
# [774]	validation_0-mae:0.223167
# [775]	validation_0-mae:0.223165
# [776]	validation_0-mae:0.22316
# [777]	validation_0-mae:0.223155
# [778]	validation_0-mae:0.223152
# [779]	validation_0-mae:0.22315
# [780]	validation_0-mae:0.223147
# [781]	validation_0-mae:0.223143
# [782]	validation_0-mae:0.223137
# [783]	validation_0-mae:0.223125
# [784]	validation_0-mae:0.223123
# [785]	validation_0-mae:0.22312
# [786]	validation_0-mae:0.223116
# [787]	validation_0-mae:0.223113
# [788]	validation_0-mae:0.223109
# [789]	validation_0-mae:0.223106
# [790]	validation_0-mae:0.223102
# [791]	validation_0-mae:0.2231
# [792]	validation_0-mae:0.223098
# [793]	validation_0-mae:0.223093
# [794]	validation_0-mae:0.223089
# [795]	validation_0-mae:0.223088
# [796]	validation_0-mae:0.223083
# [797]	validation_0-mae:0.223079
# [798]	validation_0-mae:0.223074
# [799]	validation_0-mae:0.223071
# [800]	validation_0-mae:0.22307
# [801]	validation_0-mae:0.223068
# [802]	validation_0-mae:0.223066
# [803]	validation_0-mae:0.223064
# [804]	validation_0-mae:0.223062
# [805]	validation_0-mae:0.223059
# [806]	validation_0-mae:0.22305
# [807]	validation_0-mae:0.223048
# [808]	validation_0-mae:0.223044
# [809]	validation_0-mae:0.223037
# [810]	validation_0-mae:0.223036
# [811]	validation_0-mae:0.223035
# [812]	validation_0-mae:0.223029
# [813]	validation_0-mae:0.223027
# [814]	validation_0-mae:0.223024
# [815]	validation_0-mae:0.223017
# [816]	validation_0-mae:0.223014
# [817]	validation_0-mae:0.223012
# [818]	validation_0-mae:0.223005
# [819]	validation_0-mae:0.223003
# [820]	validation_0-mae:0.223001
# [821]	validation_0-mae:0.223
# [822]	validation_0-mae:0.222999
# [823]	validation_0-mae:0.222998
# [824]	validation_0-mae:0.222996
# [825]	validation_0-mae:0.222992
# [826]	validation_0-mae:0.22299
# [827]	validation_0-mae:0.222987
# [828]	validation_0-mae:0.222986
# [829]	validation_0-mae:0.222982
# [830]	validation_0-mae:0.222981
# [831]	validation_0-mae:0.222979
# [832]	validation_0-mae:0.222977
# [833]	validation_0-mae:0.222975
# [834]	validation_0-mae:0.22297
# [835]	validation_0-mae:0.222969
# [836]	validation_0-mae:0.222968
# [837]	validation_0-mae:0.222963
# [838]	validation_0-mae:0.222957
# [839]	validation_0-mae:0.222953
# [840]	validation_0-mae:0.222951
# [841]	validation_0-mae:0.222948
# [842]	validation_0-mae:0.222945
# [843]	validation_0-mae:0.222945
# [844]	validation_0-mae:0.222942
# [845]	validation_0-mae:0.222939
# [846]	validation_0-mae:0.222935
# [847]	validation_0-mae:0.222932
# [848]	validation_0-mae:0.222931
# [849]	validation_0-mae:0.222928
# [850]	validation_0-mae:0.222927
# [851]	validation_0-mae:0.222927
# [852]	validation_0-mae:0.222925
# [853]	validation_0-mae:0.222923
# [854]	validation_0-mae:0.222922
# [855]	validation_0-mae:0.222921
# [856]	validation_0-mae:0.222919
# [857]	validation_0-mae:0.222912
# [858]	validation_0-mae:0.22291
# [859]	validation_0-mae:0.222909
# [860]	validation_0-mae:0.222908
# [861]	validation_0-mae:0.222906
# [862]	validation_0-mae:0.222906
# [863]	validation_0-mae:0.222904
# [864]	validation_0-mae:0.222903
# [865]	validation_0-mae:0.222901
# [866]	validation_0-mae:0.222899
# [867]	validation_0-mae:0.222898
# [868]	validation_0-mae:0.222896
# [869]	validation_0-mae:0.222895
# [870]	validation_0-mae:0.222894
# [871]	validation_0-mae:0.222892
# [872]	validation_0-mae:0.222891
# [873]	validation_0-mae:0.222888
# [874]	validation_0-mae:0.222886
# [875]	validation_0-mae:0.222885
# [876]	validation_0-mae:0.222882
# [877]	validation_0-mae:0.222882
# [878]	validation_0-mae:0.222881
# [879]	validation_0-mae:0.222876
# [880]	validation_0-mae:0.222874
# [881]	validation_0-mae:0.222872
# [882]	validation_0-mae:0.22287
# [883]	validation_0-mae:0.222869
# [884]	validation_0-mae:0.222867
# [885]	validation_0-mae:0.222867
# [886]	validation_0-mae:0.222867
# [887]	validation_0-mae:0.222866
# [888]	validation_0-mae:0.222864
# [889]	validation_0-mae:0.222864
# [890]	validation_0-mae:0.222863
# [891]	validation_0-mae:0.222861
# [892]	validation_0-mae:0.22286
# [893]	validation_0-mae:0.22286
# [894]	validation_0-mae:0.222857
# [895]	validation_0-mae:0.222852
# [896]	validation_0-mae:0.222847
# [897]	validation_0-mae:0.222845
# [898]	validation_0-mae:0.222844
# [899]	validation_0-mae:0.222841
# [900]	validation_0-mae:0.22284
# [901]	validation_0-mae:0.222839
# [902]	validation_0-mae:0.222837
# [903]	validation_0-mae:0.222836
# [904]	validation_0-mae:0.222835
# [905]	validation_0-mae:0.222834
# [906]	validation_0-mae:0.222834
# [907]	validation_0-mae:0.222834
# [908]	validation_0-mae:0.222834
# [909]	validation_0-mae:0.222831
# [910]	validation_0-mae:0.22283
# [911]	validation_0-mae:0.222828
# [912]	validation_0-mae:0.222825
# [913]	validation_0-mae:0.222825
# [914]	validation_0-mae:0.22282
# [915]	validation_0-mae:0.222818
# [916]	validation_0-mae:0.222815
# [917]	validation_0-mae:0.222811
# [918]	validation_0-mae:0.22281
# [919]	validation_0-mae:0.22281
# [920]	validation_0-mae:0.22281
# [921]	validation_0-mae:0.22281
# [922]	validation_0-mae:0.222804
# [923]	validation_0-mae:0.222803
# [924]	validation_0-mae:0.2228
# [925]	validation_0-mae:0.222799
# [926]	validation_0-mae:0.222796
# [927]	validation_0-mae:0.222796
# [928]	validation_0-mae:0.222795
# [929]	validation_0-mae:0.222791
# [930]	validation_0-mae:0.222789
# [931]	validation_0-mae:0.222788
# [932]	validation_0-mae:0.222788
# [933]	validation_0-mae:0.222783
# [934]	validation_0-mae:0.222782
# [935]	validation_0-mae:0.222777
# [936]	validation_0-mae:0.222774
# [937]	validation_0-mae:0.222774
# [938]	validation_0-mae:0.222773
# [939]	validation_0-mae:0.222772
# [940]	validation_0-mae:0.222769
# [941]	validation_0-mae:0.222767
# [942]	validation_0-mae:0.222765
# [943]	validation_0-mae:0.222762
# [944]	validation_0-mae:0.222761
# [945]	validation_0-mae:0.222757
# [946]	validation_0-mae:0.222755
# [947]	validation_0-mae:0.222754
# [948]	validation_0-mae:0.222752
# [949]	validation_0-mae:0.22275
# [950]	validation_0-mae:0.222744
# [951]	validation_0-mae:0.222744
# [952]	validation_0-mae:0.222741
# [953]	validation_0-mae:0.222741
# [954]	validation_0-mae:0.222737
# [955]	validation_0-mae:0.222736
# [956]	validation_0-mae:0.222735
# [957]	validation_0-mae:0.222734
# [958]	validation_0-mae:0.22273
# [959]	validation_0-mae:0.222729
# [960]	validation_0-mae:0.222728
# [961]	validation_0-mae:0.222728
# [962]	validation_0-mae:0.222727
# [963]	validation_0-mae:0.222726
# [964]	validation_0-mae:0.222721
# [965]	validation_0-mae:0.222716
# [966]	validation_0-mae:0.222716
# [967]	validation_0-mae:0.222715
# [968]	validation_0-mae:0.222714
# [969]	validation_0-mae:0.222713
# [970]	validation_0-mae:0.222711
# [971]	validation_0-mae:0.222707
# [972]	validation_0-mae:0.222706
# [973]	validation_0-mae:0.222706
# [974]	validation_0-mae:0.222706
# [975]	validation_0-mae:0.222705
# [976]	validation_0-mae:0.222703
# [977]	validation_0-mae:0.222704
# [978]	validation_0-mae:0.222703
# [979]	validation_0-mae:0.222703
# [980]	validation_0-mae:0.222702
# [981]	validation_0-mae:0.222702
# [982]	validation_0-mae:0.2227
# [983]	validation_0-mae:0.222699
# [984]	validation_0-mae:0.222698
# [985]	validation_0-mae:0.222696
# [986]	validation_0-mae:0.222696
# [987]	validation_0-mae:0.222695
# [988]	validation_0-mae:0.222694
# [989]	validation_0-mae:0.222694
# [990]	validation_0-mae:0.222693
# [991]	validation_0-mae:0.222693
# [992]	validation_0-mae:0.222693
# [993]	validation_0-mae:0.222692
# [994]	validation_0-mae:0.222691
# [995]	validation_0-mae:0.22269
# [996]	validation_0-mae:0.222687
# [997]	validation_0-mae:0.222686
# [998]	validation_0-mae:0.222684
# [999]	validation_0-mae:0.222684
# [CV]  colsample_bytree=0.75, learning_rate=0.01, min_child_weight=3, n_estimators=1000, subsample=0.75, max_depth=25, gamma=0.3, score=-0.220305992829, total=19.0min
# [CV] colsample_bytree=0.75, learning_rate=0.01, min_child_weight=3, n_estimators=1000, subsample=0.75, max_depth=25, gamma=0.3
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 19.5min remaining:    0.0s
# [0]	validation_0-mae:8.90392
# Will train until validation_0-mae hasn't improved in 20 rounds.
# [1]	validation_0-mae:8.81492
# [2]	validation_0-mae:8.72679
# [3]	validation_0-mae:8.63954
# [4]	validation_0-mae:8.55317
# [5]	validation_0-mae:8.46765
# [6]	validation_0-mae:8.38299
# [7]	validation_0-mae:8.29917
# [8]	validation_0-mae:8.2162
# [9]	validation_0-mae:8.13407
# [10]	validation_0-mae:8.05277
# [11]	validation_0-mae:7.97227
# [12]	validation_0-mae:7.89258
# [13]	validation_0-mae:7.81368
# [14]	validation_0-mae:7.73555
# [15]	validation_0-mae:7.65823
# [16]	validation_0-mae:7.58167
# [17]	validation_0-mae:7.50587
# [18]	validation_0-mae:7.43083
# [19]	validation_0-mae:7.35655
# [20]	validation_0-mae:7.28301
# [21]	validation_0-mae:7.21019
# [22]	validation_0-mae:7.13811
# [23]	validation_0-mae:7.06676
# [24]	validation_0-mae:6.99612
# [25]	validation_0-mae:6.92619
# [26]	validation_0-mae:6.85695
# [27]	validation_0-mae:6.78841
# [28]	validation_0-mae:6.72056
# [29]	validation_0-mae:6.65339
# [30]	validation_0-mae:6.58688
# [31]	validation_0-mae:6.52103
# [32]	validation_0-mae:6.45584
# [33]	validation_0-mae:6.3913
# [34]	validation_0-mae:6.3274
# [35]	validation_0-mae:6.26415
# [36]	validation_0-mae:6.20153
# [37]	validation_0-mae:6.13954
# [38]	validation_0-mae:6.07818
# [39]	validation_0-mae:6.01741
# [40]	validation_0-mae:5.95726
# [41]	validation_0-mae:5.89771
# [42]	validation_0-mae:5.83877
# [43]	validation_0-mae:5.78041
# [44]	validation_0-mae:5.72262
# [45]	validation_0-mae:5.66542
# [46]	validation_0-mae:5.6088
# [47]	validation_0-mae:5.55274
# [48]	validation_0-mae:5.49724
# [49]	validation_0-mae:5.44229
# [50]	validation_0-mae:5.38788
# [51]	validation_0-mae:5.33402
# [52]	validation_0-mae:5.28071
# [53]	validation_0-mae:5.22793
# [54]	validation_0-mae:5.17567
# [55]	validation_0-mae:5.12393
# [56]	validation_0-mae:5.07272
# [57]	validation_0-mae:5.02201
# [58]	validation_0-mae:4.97181
# [59]	validation_0-mae:4.92212
# [60]	validation_0-mae:4.87293
# [61]	validation_0-mae:4.82422
# [62]	validation_0-mae:4.77601
# [63]	validation_0-mae:4.72827
# [64]	validation_0-mae:4.68101
# [65]	validation_0-mae:4.63422
# [66]	validation_0-mae:4.58791
# [67]	validation_0-mae:4.54206
# [68]	validation_0-mae:4.49667
# [69]	validation_0-mae:4.45174
# [70]	validation_0-mae:4.40725
# [71]	validation_0-mae:4.36321
# [72]	validation_0-mae:4.3196
# [73]	validation_0-mae:4.27644
# [74]	validation_0-mae:4.23369
# [75]	validation_0-mae:4.19138
# [76]	validation_0-mae:4.14948
# [77]	validation_0-mae:4.10801
# [78]	validation_0-mae:4.06696
# [79]	validation_0-mae:4.02632
# [80]	validation_0-mae:3.98608
# [81]	validation_0-mae:3.94625
# [82]	validation_0-mae:3.90682
# [83]	validation_0-mae:3.86777
# [84]	validation_0-mae:3.82911
# [85]	validation_0-mae:3.79084
# [86]	validation_0-mae:3.75295
# [87]	validation_0-mae:3.71545
# [88]	validation_0-mae:3.67833
# [89]	validation_0-mae:3.64158
# [90]	validation_0-mae:3.6052
# [91]	validation_0-mae:3.56917
# [92]	validation_0-mae:3.5335
# [93]	validation_0-mae:3.49819
# [94]	validation_0-mae:3.46323
# [95]	validation_0-mae:3.42862
# [96]	validation_0-mae:3.39436
# [97]	validation_0-mae:3.36044
# [98]	validation_0-mae:3.32685
# [99]	validation_0-mae:3.29361
# [100]	validation_0-mae:3.2607
# [101]	validation_0-mae:3.22812
# [102]	validation_0-mae:3.19587
# [103]	validation_0-mae:3.16394
# [104]	validation_0-mae:3.13233
# [105]	validation_0-mae:3.10103
# [106]	validation_0-mae:3.07005
# [107]	validation_0-mae:3.03937
# [108]	validation_0-mae:3.00899
# [109]	validation_0-mae:2.97892
# [110]	validation_0-mae:2.94916
# [111]	validation_0-mae:2.91969
# [112]	validation_0-mae:2.89051
# [113]	validation_0-mae:2.86162
# [114]	validation_0-mae:2.83302
# [115]	validation_0-mae:2.80472
# [116]	validation_0-mae:2.77671
# [117]	validation_0-mae:2.74896
# [118]	validation_0-mae:2.72149
# [119]	validation_0-mae:2.6943
# [120]	validation_0-mae:2.66737
# [121]	validation_0-mae:2.64073
# [122]	validation_0-mae:2.61435
# [123]	validation_0-mae:2.58823
# [124]	validation_0-mae:2.56237
# [125]	validation_0-mae:2.53678
# [126]	validation_0-mae:2.51143
# [127]	validation_0-mae:2.48635
# [128]	validation_0-mae:2.46151
# [129]	validation_0-mae:2.43691
# [130]	validation_0-mae:2.41257
# [131]	validation_0-mae:2.38848
# [132]	validation_0-mae:2.36462
# [133]	validation_0-mae:2.341
# [134]	validation_0-mae:2.31762
# [135]	validation_0-mae:2.29448
# [136]	validation_0-mae:2.27156
# [137]	validation_0-mae:2.24888
# [138]	validation_0-mae:2.22641
# [139]	validation_0-mae:2.20418
# [140]	validation_0-mae:2.18215
# [141]	validation_0-mae:2.16036
# [142]	validation_0-mae:2.13879
# [143]	validation_0-mae:2.11744
# [144]	validation_0-mae:2.0963
# [145]	validation_0-mae:2.07537
# [146]	validation_0-mae:2.05465
# [147]	validation_0-mae:2.03413
# [148]	validation_0-mae:2.01383
# [149]	validation_0-mae:1.99373
# [150]	validation_0-mae:1.97382
# [151]	validation_0-mae:1.95409
# [152]	validation_0-mae:1.93459
# [153]	validation_0-mae:1.91528
# [154]	validation_0-mae:1.89616
# [155]	validation_0-mae:1.87723
# [156]	validation_0-mae:1.85849
# [157]	validation_0-mae:1.83993
# [158]	validation_0-mae:1.82158
# [159]	validation_0-mae:1.8034
# [160]	validation_0-mae:1.7854
# [161]	validation_0-mae:1.76757
# [162]	validation_0-mae:1.74994
# [163]	validation_0-mae:1.73247
# [164]	validation_0-mae:1.71518
# [165]	validation_0-mae:1.69808
# [166]	validation_0-mae:1.68114
# [167]	validation_0-mae:1.66437
# [168]	validation_0-mae:1.64777
# [169]	validation_0-mae:1.63135
# [170]	validation_0-mae:1.61507
# [171]	validation_0-mae:1.59896
# [172]	validation_0-mae:1.58302
# [173]	validation_0-mae:1.56725
# [174]	validation_0-mae:1.55164
# [175]	validation_0-mae:1.53617
# [176]	validation_0-mae:1.52087
# [177]	validation_0-mae:1.50573
# [178]	validation_0-mae:1.49072
# [179]	validation_0-mae:1.47587
# [180]	validation_0-mae:1.46117
# [181]	validation_0-mae:1.44661
# [182]	validation_0-mae:1.43222
# [183]	validation_0-mae:1.41795
# [184]	validation_0-mae:1.40383
# [185]	validation_0-mae:1.38986
# [186]	validation_0-mae:1.37602
# [187]	validation_0-mae:1.36233
# [188]	validation_0-mae:1.34879
# [189]	validation_0-mae:1.33537
# [190]	validation_0-mae:1.32211
# [191]	validation_0-mae:1.30899
# [192]	validation_0-mae:1.29599
# [193]	validation_0-mae:1.28312
# [194]	validation_0-mae:1.27038
# [195]	validation_0-mae:1.25777
# [196]	validation_0-mae:1.24529
# [197]	validation_0-mae:1.23293
# [198]	validation_0-mae:1.22071
# [199]	validation_0-mae:1.2086
# [200]	validation_0-mae:1.19663
# [201]	validation_0-mae:1.18478
# [202]	validation_0-mae:1.17305
# [203]	validation_0-mae:1.16145
# [204]	validation_0-mae:1.14995
# [205]	validation_0-mae:1.13859
# [206]	validation_0-mae:1.12736
# [207]	validation_0-mae:1.11621
# [208]	validation_0-mae:1.10519
# [209]	validation_0-mae:1.0943
# [210]	validation_0-mae:1.08351
# [211]	validation_0-mae:1.07285
# [212]	validation_0-mae:1.06228
# [213]	validation_0-mae:1.05184
# [214]	validation_0-mae:1.04149
# [215]	validation_0-mae:1.03128
# [216]	validation_0-mae:1.02119
# [217]	validation_0-mae:1.01118
# [218]	validation_0-mae:1.00128
# [219]	validation_0-mae:0.991466
# [220]	validation_0-mae:0.981783
# [221]	validation_0-mae:0.972195
# [222]	validation_0-mae:0.962704
# [223]	validation_0-mae:0.953337
# [224]	validation_0-mae:0.944045
# [225]	validation_0-mae:0.934864
# [226]	validation_0-mae:0.925795
# [227]	validation_0-mae:0.916818
# [228]	validation_0-mae:0.907951
# [229]	validation_0-mae:0.899168
# [230]	validation_0-mae:0.890486
# [231]	validation_0-mae:0.881883
# [232]	validation_0-mae:0.8734
# [233]	validation_0-mae:0.865003
# [234]	validation_0-mae:0.856693
# [235]	validation_0-mae:0.848478
# [236]	validation_0-mae:0.840358
# [237]	validation_0-mae:0.832313
# [238]	validation_0-mae:0.82435
# [239]	validation_0-mae:0.816485
# [240]	validation_0-mae:0.808718
# [241]	validation_0-mae:0.801039
# [242]	validation_0-mae:0.793457
# [243]	validation_0-mae:0.78596
# [244]	validation_0-mae:0.778546
# [245]	validation_0-mae:0.771211
# [246]	validation_0-mae:0.763956
# [247]	validation_0-mae:0.75676
# [248]	validation_0-mae:0.749671
# [249]	validation_0-mae:0.742661
# [250]	validation_0-mae:0.735744
# [251]	validation_0-mae:0.72887
# [252]	validation_0-mae:0.722111
# [253]	validation_0-mae:0.715415
# [254]	validation_0-mae:0.708789
# [255]	validation_0-mae:0.702239
# [256]	validation_0-mae:0.695778
# [257]	validation_0-mae:0.689385
# [258]	validation_0-mae:0.68305
# [259]	validation_0-mae:0.676786
# [260]	validation_0-mae:0.670628
# [261]	validation_0-mae:0.664536
# [262]	validation_0-mae:0.658513
# [263]	validation_0-mae:0.652535
# [264]	validation_0-mae:0.646647
# [265]	validation_0-mae:0.640833
# [266]	validation_0-mae:0.63508
# [267]	validation_0-mae:0.629397
# [268]	validation_0-mae:0.623786
# [269]	validation_0-mae:0.618242
# [270]	validation_0-mae:0.612757
# [271]	validation_0-mae:0.607357
# [272]	validation_0-mae:0.602006
# [273]	validation_0-mae:0.596705
# [274]	validation_0-mae:0.59149
# [275]	validation_0-mae:0.586338
# [276]	validation_0-mae:0.581245
# [277]	validation_0-mae:0.576229
# [278]	validation_0-mae:0.571258
# [279]	validation_0-mae:0.566349
# [280]	validation_0-mae:0.561501
# [281]	validation_0-mae:0.556721
# [282]	validation_0-mae:0.551996
# [283]	validation_0-mae:0.547323
# [284]	validation_0-mae:0.542714
# [285]	validation_0-mae:0.538163
# [286]	validation_0-mae:0.533649
# [287]	validation_0-mae:0.529207
# [288]	validation_0-mae:0.524817
# [289]	validation_0-mae:0.52049
# [290]	validation_0-mae:0.516209
# [291]	validation_0-mae:0.511984
# [292]	validation_0-mae:0.507818
# [293]	validation_0-mae:0.503704
# [294]	validation_0-mae:0.499633
# [295]	validation_0-mae:0.49562
# [296]	validation_0-mae:0.491652
# [297]	validation_0-mae:0.487731
# [298]	validation_0-mae:0.483872
# [299]	validation_0-mae:0.480069
# [300]	validation_0-mae:0.476299
# [301]	validation_0-mae:0.472578
# [302]	validation_0-mae:0.468911
# [303]	validation_0-mae:0.4653
# [304]	validation_0-mae:0.461724
# [305]	validation_0-mae:0.458196
# [306]	validation_0-mae:0.454723
# [307]	validation_0-mae:0.451291
# [308]	validation_0-mae:0.447903
# [309]	validation_0-mae:0.444539
# [310]	validation_0-mae:0.441234
# [311]	validation_0-mae:0.437962
# [312]	validation_0-mae:0.434752
# [313]	validation_0-mae:0.43158
# [314]	validation_0-mae:0.428443
# [315]	validation_0-mae:0.425347
# [316]	validation_0-mae:0.42229
# [317]	validation_0-mae:0.41928
# [318]	validation_0-mae:0.416319
# [319]	validation_0-mae:0.4134
# [320]	validation_0-mae:0.41051
# [321]	validation_0-mae:0.407668
# [322]	validation_0-mae:0.404849
# [323]	validation_0-mae:0.402096
# [324]	validation_0-mae:0.39937
# [325]	validation_0-mae:0.396686
# [326]	validation_0-mae:0.394034
# [327]	validation_0-mae:0.391423
# [328]	validation_0-mae:0.388841
# [329]	validation_0-mae:0.3863
# [330]	validation_0-mae:0.383817
# [331]	validation_0-mae:0.381355
# [332]	validation_0-mae:0.378921
# [333]	validation_0-mae:0.376519
# [334]	validation_0-mae:0.374149
# [335]	validation_0-mae:0.371795
# [336]	validation_0-mae:0.3695
# [337]	validation_0-mae:0.367223
# [338]	validation_0-mae:0.364979
# [339]	validation_0-mae:0.362767
# [340]	validation_0-mae:0.360589
# [341]	validation_0-mae:0.358432
# [342]	validation_0-mae:0.356317
# [343]	validation_0-mae:0.354224
# [344]	validation_0-mae:0.35217
# [345]	validation_0-mae:0.350136
# [346]	validation_0-mae:0.34814
# [347]	validation_0-mae:0.34617
# [348]	validation_0-mae:0.344223
# [349]	validation_0-mae:0.342313
# [350]	validation_0-mae:0.340429
# [351]	validation_0-mae:0.338565
# [352]	validation_0-mae:0.336732
# [353]	validation_0-mae:0.334921
# [354]	validation_0-mae:0.333146
# [355]	validation_0-mae:0.3314
# [356]	validation_0-mae:0.329688
# [357]	validation_0-mae:0.327993
# [358]	validation_0-mae:0.326327
# [359]	validation_0-mae:0.324674
# [360]	validation_0-mae:0.323055
# [361]	validation_0-mae:0.321462
# [362]	validation_0-mae:0.319881
# [363]	validation_0-mae:0.31833
# [364]	validation_0-mae:0.316799
# [365]	validation_0-mae:0.315297
# [366]	validation_0-mae:0.313812
# [367]	validation_0-mae:0.31236
# [368]	validation_0-mae:0.310923
# [369]	validation_0-mae:0.309516
# [370]	validation_0-mae:0.308122
# [371]	validation_0-mae:0.30675
# [372]	validation_0-mae:0.3054
# [373]	validation_0-mae:0.304074
# [374]	validation_0-mae:0.302768
# [375]	validation_0-mae:0.301478
# [376]	validation_0-mae:0.300202
# [377]	validation_0-mae:0.29896
# [378]	validation_0-mae:0.297732
# [379]	validation_0-mae:0.296514
# [380]	validation_0-mae:0.295327
# [381]	validation_0-mae:0.294145
# [382]	validation_0-mae:0.292995
# [383]	validation_0-mae:0.29186
# [384]	validation_0-mae:0.290737
# [385]	validation_0-mae:0.289633
# [386]	validation_0-mae:0.288546
# [387]	validation_0-mae:0.287475
# [388]	validation_0-mae:0.286418
# [389]	validation_0-mae:0.285378
# [390]	validation_0-mae:0.284355
# [391]	validation_0-mae:0.283351
# [392]	validation_0-mae:0.282363
# [393]	validation_0-mae:0.281383
# [394]	validation_0-mae:0.280428
# [395]	validation_0-mae:0.279478
# [396]	validation_0-mae:0.278555
# [397]	validation_0-mae:0.277637
# [398]	validation_0-mae:0.276742
# [399]	validation_0-mae:0.27586
# [400]	validation_0-mae:0.275
# [401]	validation_0-mae:0.274152
# [402]	validation_0-mae:0.273316
# [403]	validation_0-mae:0.27249
# [404]	validation_0-mae:0.271682
# [405]	validation_0-mae:0.270878
# [406]	validation_0-mae:0.270085
# [407]	validation_0-mae:0.269311
# [408]	validation_0-mae:0.26855
# [409]	validation_0-mae:0.2678
# [410]	validation_0-mae:0.267064
# [411]	validation_0-mae:0.266331
# [412]	validation_0-mae:0.265611
# [413]	validation_0-mae:0.264909
# [414]	validation_0-mae:0.26421
# [415]	validation_0-mae:0.263536
# [416]	validation_0-mae:0.262874
# [417]	validation_0-mae:0.262209
# [418]	validation_0-mae:0.261554
# [419]	validation_0-mae:0.260913
# [420]	validation_0-mae:0.260285
# [421]	validation_0-mae:0.259677
# [422]	validation_0-mae:0.259075
# [423]	validation_0-mae:0.258476
# [424]	validation_0-mae:0.257885
# [425]	validation_0-mae:0.2573
# [426]	validation_0-mae:0.256729
# [427]	validation_0-mae:0.256179
# [428]	validation_0-mae:0.255623
# [429]	validation_0-mae:0.255082
# [430]	validation_0-mae:0.254551
# [431]	validation_0-mae:0.254022
# [432]	validation_0-mae:0.253506
# [433]	validation_0-mae:0.253
# [434]	validation_0-mae:0.252503
# [435]	validation_0-mae:0.252008
# [436]	validation_0-mae:0.251528
# [437]	validation_0-mae:0.251064
# [438]	validation_0-mae:0.2506
# [439]	validation_0-mae:0.250149
# [440]	validation_0-mae:0.249701
# [441]	validation_0-mae:0.249258
# [442]	validation_0-mae:0.248828
# [443]	validation_0-mae:0.2484
# [444]	validation_0-mae:0.24798
# [445]	validation_0-mae:0.247565
# [446]	validation_0-mae:0.247162
# [447]	validation_0-mae:0.246753
# [448]	validation_0-mae:0.246363
# [449]	validation_0-mae:0.245983
# [450]	validation_0-mae:0.245606
# [451]	validation_0-mae:0.245228
# [452]	validation_0-mae:0.24486
# [453]	validation_0-mae:0.244509
# [454]	validation_0-mae:0.244154
# [455]	validation_0-mae:0.243801
# [456]	validation_0-mae:0.243452
# [457]	validation_0-mae:0.243119
# [458]	validation_0-mae:0.242786
# [459]	validation_0-mae:0.242452
# [460]	validation_0-mae:0.242133
# [461]	validation_0-mae:0.241816
# [462]	validation_0-mae:0.241502
# [463]	validation_0-mae:0.241204
# [464]	validation_0-mae:0.240903
# [465]	validation_0-mae:0.240602
# [466]	validation_0-mae:0.240299
# [467]	validation_0-mae:0.240026
# [468]	validation_0-mae:0.239749
# [469]	validation_0-mae:0.239473
# [470]	validation_0-mae:0.239204
# [471]	validation_0-mae:0.23894
# [472]	validation_0-mae:0.23868
# [473]	validation_0-mae:0.238428
# [474]	validation_0-mae:0.238172
# [475]	validation_0-mae:0.237929
# [476]	validation_0-mae:0.237685
# [477]	validation_0-mae:0.237452
# [478]	validation_0-mae:0.237215
# [479]	validation_0-mae:0.236985
# [480]	validation_0-mae:0.236755
# [481]	validation_0-mae:0.236539
# [482]	validation_0-mae:0.236321
# [483]	validation_0-mae:0.236103
# [484]	validation_0-mae:0.235887
# [485]	validation_0-mae:0.235672
# [486]	validation_0-mae:0.235464
# [487]	validation_0-mae:0.235266
# [488]	validation_0-mae:0.235072
# [489]	validation_0-mae:0.234881
# [490]	validation_0-mae:0.234685
# [491]	validation_0-mae:0.23449
# [492]	validation_0-mae:0.2343
# [493]	validation_0-mae:0.23411
# [494]	validation_0-mae:0.233924
# ...
# [503]	validation_0-mae:0.231729
# [504]	validation_0-mae:0.231577
# [505]	validation_0-mae:0.231436
# [506]	validation_0-mae:0.231292
# [507]	validation_0-mae:0.231151
# [508]	validation_0-mae:0.231005
# [509]	validation_0-mae:0.230867
# [510]	validation_0-mae:0.230735
# [511]	validation_0-mae:0.2306
# [512]	validation_0-mae:0.230467
# [513]	validation_0-mae:0.230335
# [514]	validation_0-mae:0.230211
# [515]	validation_0-mae:0.23009
# [516]	validation_0-mae:0.229972
# [517]	validation_0-mae:0.229852
# [518]	validation_0-mae:0.229736
# [519]	validation_0-mae:0.229612
# [520]	validation_0-mae:0.229494
# [521]	validation_0-mae:0.22938
# [522]	validation_0-mae:0.229271
# [523]	validation_0-mae:0.22916
# [524]	validation_0-mae:0.229057
# [525]	validation_0-mae:0.228954
# [526]	validation_0-mae:0.228845
# [527]	validation_0-mae:0.228749
# [528]	validation_0-mae:0.228654
# [529]	validation_0-mae:0.228558
# [530]	validation_0-mae:0.228462
# [531]	validation_0-mae:0.228371
# [532]	validation_0-mae:0.228279
# [533]	validation_0-mae:0.228187
# [534]	validation_0-mae:0.228094
# [535]	validation_0-mae:0.228
# [536]	validation_0-mae:0.227911
# [537]	validation_0-mae:0.227824
# [538]	validation_0-mae:0.227733
# [539]	validation_0-mae:0.227649
# [540]	validation_0-mae:0.227564
# [541]	validation_0-mae:0.227479
# [542]	validation_0-mae:0.227397
# [543]	validation_0-mae:0.227319
# [544]	validation_0-mae:0.227244
# [545]	validation_0-mae:0.227172
# [546]	validation_0-mae:0.227098
# [547]	validation_0-mae:0.227021
# [548]	validation_0-mae:0.226946
# [549]	validation_0-mae:0.226876
# [550]	validation_0-mae:0.226811
# [551]	validation_0-mae:0.226741
# [552]	validation_0-mae:0.226672
# [553]	validation_0-mae:0.226607
# [554]	validation_0-mae:0.226534
# [555]	validation_0-mae:0.226474
# [556]	validation_0-mae:0.226411
# [557]	validation_0-mae:0.226343
# [558]	validation_0-mae:0.226288
# [559]	validation_0-mae:0.226231
# [560]	validation_0-mae:0.226176
# [561]	validation_0-mae:0.226121
# [562]	validation_0-mae:0.226068
# [563]	validation_0-mae:0.226012
# [564]	validation_0-mae:0.225956
# [565]	validation_0-mae:0.225896
# [566]	validation_0-mae:0.225841
# [567]	validation_0-mae:0.225784
# [568]	validation_0-mae:0.225726
# [569]	validation_0-mae:0.22568
# [570]	validation_0-mae:0.225626
# [571]	validation_0-mae:0.225573
# [572]	validation_0-mae:0.225531
# [573]	validation_0-mae:0.225484
# [574]	validation_0-mae:0.225439
# [575]	validation_0-mae:0.225392
# [576]	validation_0-mae:0.22534
# [577]	validation_0-mae:0.225297
# [578]	validation_0-mae:0.225254
# [579]	validation_0-mae:0.225214
# [580]	validation_0-mae:0.225166
# [581]	validation_0-mae:0.225125
# [582]	validation_0-mae:0.225082
# [583]	validation_0-mae:0.225042
# [584]	validation_0-mae:0.225006
# [585]	validation_0-mae:0.224967
# [586]	validation_0-mae:0.224931
# [587]	validation_0-mae:0.224889
# [588]	validation_0-mae:0.224855
# [589]	validation_0-mae:0.224818
# [590]	validation_0-mae:0.224782
# [591]	validation_0-mae:0.224743
# [592]	validation_0-mae:0.224711
# [593]	validation_0-mae:0.224673
# [594]	validation_0-mae:0.224638
# [595]	validation_0-mae:0.224607
# [596]	validation_0-mae:0.224574
# [597]	validation_0-mae:0.224546
# [598]	validation_0-mae:0.224513
# [599]	validation_0-mae:0.224484
# [600]	validation_0-mae:0.224454
# [601]	validation_0-mae:0.224419
# [602]	validation_0-mae:0.224392
# [603]	validation_0-mae:0.224366
# [604]	validation_0-mae:0.224337
# [605]	validation_0-mae:0.224309
# [606]	validation_0-mae:0.22428
# [607]	validation_0-mae:0.22425
# [608]	validation_0-mae:0.224226
# [609]	validation_0-mae:0.224203
# [610]	validation_0-mae:0.224173
# [611]	validation_0-mae:0.224147
# [612]	validation_0-mae:0.224123
# [613]	validation_0-mae:0.224093
# [614]	validation_0-mae:0.224068
# [615]	validation_0-mae:0.224043
# [616]	validation_0-mae:0.224021
# [617]	validation_0-mae:0.223992
# [618]	validation_0-mae:0.22397
# [619]	validation_0-mae:0.223949
# [620]	validation_0-mae:0.223924
# [621]	validation_0-mae:0.223904
# [622]	validation_0-mae:0.223882
# [623]	validation_0-mae:0.223862
# [624]	validation_0-mae:0.223843
# [625]	validation_0-mae:0.223821
# [626]	validation_0-mae:0.223799
# [627]	validation_0-mae:0.223777
# [628]	validation_0-mae:0.223761
# [629]	validation_0-mae:0.22374
# [630]	validation_0-mae:0.223723
# [631]	validation_0-mae:0.223704
# [632]	validation_0-mae:0.223686
# [633]	validation_0-mae:0.223666
# [634]	validation_0-mae:0.223649
# [635]	validation_0-mae:0.223632
# [636]	validation_0-mae:0.223615
# [637]	validation_0-mae:0.223596
# [638]	validation_0-mae:0.223577
# [639]	validation_0-mae:0.223561
# [640]	validation_0-mae:0.223543
# [641]	validation_0-mae:0.223524
# [642]	validation_0-mae:0.223509
# [643]	validation_0-mae:0.223493
# [644]	validation_0-mae:0.223477
# [645]	validation_0-mae:0.223463
# [646]	validation_0-mae:0.223444
# [647]	validation_0-mae:0.223433
# [648]	validation_0-mae:0.223415
# [649]	validation_0-mae:0.223403
# [650]	validation_0-mae:0.223386
# [651]	validation_0-mae:0.223373
# [652]	validation_0-mae:0.223359
# [653]	validation_0-mae:0.223346
# [654]	validation_0-mae:0.223327
# [655]	validation_0-mae:0.223313
# [656]	validation_0-mae:0.223294
# [657]	validation_0-mae:0.223278
# [658]	validation_0-mae:0.223262
# [659]	validation_0-mae:0.22325
# [660]	validation_0-mae:0.223237
# [661]	validation_0-mae:0.223221
# [662]	validation_0-mae:0.223211
# [663]	validation_0-mae:0.223199
# [664]	validation_0-mae:0.223185
# [665]	validation_0-mae:0.223176
# [666]	validation_0-mae:0.223165
# [667]	validation_0-mae:0.223153
# [668]	validation_0-mae:0.22314
# [669]	validation_0-mae:0.223131
# [670]	validation_0-mae:0.223121
# [671]	validation_0-mae:0.223112
# [672]	validation_0-mae:0.223101
# [673]	validation_0-mae:0.223091
# [674]	validation_0-mae:0.22308
# [675]	validation_0-mae:0.22307
# [676]	validation_0-mae:0.223058
# [677]	validation_0-mae:0.223047
# [678]	validation_0-mae:0.223036
# [679]	validation_0-mae:0.223024
# [680]	validation_0-mae:0.223018
# [681]	validation_0-mae:0.223007
# [682]	validation_0-mae:0.222997
# [683]	validation_0-mae:0.222988
# [684]	validation_0-mae:0.222981
# [685]	validation_0-mae:0.222973
# [686]	validation_0-mae:0.222964
# [687]	validation_0-mae:0.222955
# [688]	validation_0-mae:0.222947
# [689]	validation_0-mae:0.222938
# [690]	validation_0-mae:0.222928
# [691]	validation_0-mae:0.22292
# [692]	validation_0-mae:0.222912
# [693]	validation_0-mae:0.222903
# [694]	validation_0-mae:0.222896
# [695]	validation_0-mae:0.222882
# [696]	validation_0-mae:0.222875
# [697]	validation_0-mae:0.222869
# [698]	validation_0-mae:0.222863
# [699]	validation_0-mae:0.22285
# [700]	validation_0-mae:0.222837
# [701]	validation_0-mae:0.222829
# [702]	validation_0-mae:0.222823
# [703]	validation_0-mae:0.222818
# [704]	validation_0-mae:0.222812
# [705]	validation_0-mae:0.222808
# [706]	validation_0-mae:0.222802
# [707]	validation_0-mae:0.222792
# [708]	validation_0-mae:0.222786
# [709]	validation_0-mae:0.222781
# [710]	validation_0-mae:0.222774
# [711]	validation_0-mae:0.22277
# [712]	validation_0-mae:0.222759
# [713]	validation_0-mae:0.222753
# [714]	validation_0-mae:0.222749
# [715]	validation_0-mae:0.222744
# [716]	validation_0-mae:0.222738
# [717]	validation_0-mae:0.222733
# [718]	validation_0-mae:0.222723
# [719]	validation_0-mae:0.222716
# [720]	validation_0-mae:0.222708
# [721]	validation_0-mae:0.222702
# [722]	validation_0-mae:0.222697
# [723]	validation_0-mae:0.222691
# [724]	validation_0-mae:0.222685
# [725]	validation_0-mae:0.222679
# [726]	validation_0-mae:0.222673
# [727]	validation_0-mae:0.222663
# [728]	validation_0-mae:0.222655
# [729]	validation_0-mae:0.222648
# [730]	validation_0-mae:0.222643
# [731]	validation_0-mae:0.222639
# [732]	validation_0-mae:0.222634
# [733]	validation_0-mae:0.222626
# [734]	validation_0-mae:0.22262
# [735]	validation_0-mae:0.222615
# [736]	validation_0-mae:0.222608
# [737]	validation_0-mae:0.222603
# [738]	validation_0-mae:0.222599
# [739]	validation_0-mae:0.222593
# [740]	validation_0-mae:0.222586
# [741]	validation_0-mae:0.222579
# [742]	validation_0-mae:0.222576
# [743]	validation_0-mae:0.222573
# [744]	validation_0-mae:0.222567
# [745]	validation_0-mae:0.222561
# [746]	validation_0-mae:0.222554
# [747]	validation_0-mae:0.222546
# [748]	validation_0-mae:0.22254
# [749]	validation_0-mae:0.222537
# [750]	validation_0-mae:0.222533
# [751]	validation_0-mae:0.222529
# [752]	validation_0-mae:0.222522
# [753]	validation_0-mae:0.222514
# [754]	validation_0-mae:0.222511
# [755]	validation_0-mae:0.222507
# [756]	validation_0-mae:0.222503
# [757]	validation_0-mae:0.222498
# [758]	validation_0-mae:0.222494
# [759]	validation_0-mae:0.22249
# [760]	validation_0-mae:0.222487
# [761]	validation_0-mae:0.222484
# [762]	validation_0-mae:0.22248
# [763]	validation_0-mae:0.222476
# [764]	validation_0-mae:0.222474
# [765]	validation_0-mae:0.222471
# [766]	validation_0-mae:0.222467
# [767]	validation_0-mae:0.222463
# [768]	validation_0-mae:0.22246
# [769]	validation_0-mae:0.222454
# [770]	validation_0-mae:0.222448
# [771]	validation_0-mae:0.222439
# [772]	validation_0-mae:0.222435
# [773]	validation_0-mae:0.222432
# [774]	validation_0-mae:0.222427
# [775]	validation_0-mae:0.222422
# [776]	validation_0-mae:0.222416
# [777]	validation_0-mae:0.222413
# [778]	validation_0-mae:0.222408
# [779]	validation_0-mae:0.222405
# [780]	validation_0-mae:0.222402
# [781]	validation_0-mae:0.222398
# [782]	validation_0-mae:0.222396
# [783]	validation_0-mae:0.222392
# [784]	validation_0-mae:0.222383
# [785]	validation_0-mae:0.222381
# [786]	validation_0-mae:0.222378
# [787]	validation_0-mae:0.222375
# [788]	validation_0-mae:0.22237
# [789]	validation_0-mae:0.222368
# [790]	validation_0-mae:0.222364
# [791]	validation_0-mae:0.222361
# [792]	validation_0-mae:0.222359
# [793]	validation_0-mae:0.222354
# [794]	validation_0-mae:0.222353
# [795]	validation_0-mae:0.222351
# [796]	validation_0-mae:0.222349
# [797]	validation_0-mae:0.222346
# [798]	validation_0-mae:0.222343
# [799]	validation_0-mae:0.222339
# [800]	validation_0-mae:0.222337
# [801]	validation_0-mae:0.222332
# [802]	validation_0-mae:0.22233
# [803]	validation_0-mae:0.222327
# [804]	validation_0-mae:0.222324
# [805]	validation_0-mae:0.222323
# [806]	validation_0-mae:0.222322
# [807]	validation_0-mae:0.222315
# [808]	validation_0-mae:0.222314
# [809]	validation_0-mae:0.222312
# [810]	validation_0-mae:0.222307
# [811]	validation_0-mae:0.222305
# [812]	validation_0-mae:0.222302
# [813]	validation_0-mae:0.222301
# [814]	validation_0-mae:0.222298
# [815]	validation_0-mae:0.222295
# [816]	validation_0-mae:0.222292
# [817]	validation_0-mae:0.22229
# [818]	validation_0-mae:0.222287
# [819]	validation_0-mae:0.222282
# [820]	validation_0-mae:0.222281
# [821]	validation_0-mae:0.222279
# [822]	validation_0-mae:0.222273
# [823]	validation_0-mae:0.22227
# [824]	validation_0-mae:0.222267
# [825]	validation_0-mae:0.222264
# [826]	validation_0-mae:0.222259
# [827]	validation_0-mae:0.222258
# [828]	validation_0-mae:0.222255
# [829]	validation_0-mae:0.222253
# [830]	validation_0-mae:0.222246
# [831]	validation_0-mae:0.222244
# [832]	validation_0-mae:0.22224
# [833]	validation_0-mae:0.222236
# [834]	validation_0-mae:0.222234
# [835]	validation_0-mae:0.22223
# [836]	validation_0-mae:0.222228
# [837]	validation_0-mae:0.222226
# [838]	validation_0-mae:0.222225
# [839]	validation_0-mae:0.222221
# [840]	validation_0-mae:0.22222
# [841]	validation_0-mae:0.222219
# [842]	validation_0-mae:0.222213
# [843]	validation_0-mae:0.22221
# [844]	validation_0-mae:0.222207
# [845]	validation_0-mae:0.222206
# [846]	validation_0-mae:0.222204
# [847]	validation_0-mae:0.222196
# [848]	validation_0-mae:0.222195
# [849]	validation_0-mae:0.222194
# [850]	validation_0-mae:0.222191
# [851]	validation_0-mae:0.22219
# [852]	validation_0-mae:0.222188
# [853]	validation_0-mae:0.222184
# [854]	validation_0-mae:0.222179
# [855]	validation_0-mae:0.222175
# [856]	validation_0-mae:0.22217
# [857]	validation_0-mae:0.222165
# [858]	validation_0-mae:0.222163
# [859]	validation_0-mae:0.222162
# [860]	validation_0-mae:0.22216
# [861]	validation_0-mae:0.222159
# [862]	validation_0-mae:0.222158
# [863]	validation_0-mae:0.222157
# [864]	validation_0-mae:0.222156
# [865]	validation_0-mae:0.222155
# [866]	validation_0-mae:0.222152
# [867]	validation_0-mae:0.222149
# [868]	validation_0-mae:0.222147
# [869]	validation_0-mae:0.222143
# [870]	validation_0-mae:0.222142
# [871]	validation_0-mae:0.222141
# [872]	validation_0-mae:0.22214
# [873]	validation_0-mae:0.222138
# [874]	validation_0-mae:0.222137
# [875]	validation_0-mae:0.222132
# [876]	validation_0-mae:0.222132
# [877]	validation_0-mae:0.222131
# [878]	validation_0-mae:0.222129
# [879]	validation_0-mae:0.222127
# [880]	validation_0-mae:0.222125
# [881]	validation_0-mae:0.222121
# [882]	validation_0-mae:0.22212
# [883]	validation_0-mae:0.222118
# [884]	validation_0-mae:0.222113
# [885]	validation_0-mae:0.222106
# [886]	validation_0-mae:0.222105
# [887]	validation_0-mae:0.222101
# [888]	validation_0-mae:0.2221
# [889]	validation_0-mae:0.222099
# [890]	validation_0-mae:0.222098
# [891]	validation_0-mae:0.222095
# [892]	validation_0-mae:0.222095
# [893]	validation_0-mae:0.222093
# [894]	validation_0-mae:0.222092
# [895]	validation_0-mae:0.222092
# [896]	validation_0-mae:0.222091
# [897]	validation_0-mae:0.222088
# [898]	validation_0-mae:0.222088
# [899]	validation_0-mae:0.222085
# [900]	validation_0-mae:0.222087
# [901]	validation_0-mae:0.222086
# [902]	validation_0-mae:0.222082
# [903]	validation_0-mae:0.222081
# [904]	validation_0-mae:0.22208
# [905]	validation_0-mae:0.222077
# [906]	validation_0-mae:0.222073
# [907]	validation_0-mae:0.222073
# [908]	validation_0-mae:0.22207
# [909]	validation_0-mae:0.222069
# [910]	validation_0-mae:0.222066
# [911]	validation_0-mae:0.222063
# [912]	validation_0-mae:0.222059
# [913]	validation_0-mae:0.222058
# [914]	validation_0-mae:0.222054
# [915]	validation_0-mae:0.222053
# [916]	validation_0-mae:0.222052
# [917]	validation_0-mae:0.22205
# [918]	validation_0-mae:0.22205
# [919]	validation_0-mae:0.222048
# [920]	validation_0-mae:0.222048
# [921]	validation_0-mae:0.222046
# [922]	validation_0-mae:0.222046
# [923]	validation_0-mae:0.222045
# [924]	validation_0-mae:0.222043
# [925]	validation_0-mae:0.222042
# [926]	validation_0-mae:0.222039
# [927]	validation_0-mae:0.222037
# [928]	validation_0-mae:0.222035
# [929]	validation_0-mae:0.222034
# [930]	validation_0-mae:0.222032
# [931]	validation_0-mae:0.222032
# [932]	validation_0-mae:0.222029
# [933]	validation_0-mae:0.222029
# [934]	validation_0-mae:0.222028
# [935]	validation_0-mae:0.222028
# [936]	validation_0-mae:0.222026
# [937]	validation_0-mae:0.222026
# [938]	validation_0-mae:0.222025
# [939]	validation_0-mae:0.222022
# [940]	validation_0-mae:0.222021
# [941]	validation_0-mae:0.22202
# [942]	validation_0-mae:0.222017
# [943]	validation_0-mae:0.222013
# [944]	validation_0-mae:0.222013
# [945]	validation_0-mae:0.222012
# [946]	validation_0-mae:0.22201
# [947]	validation_0-mae:0.222008
# [948]	validation_0-mae:0.222007
# [949]	validation_0-mae:0.222006
# [950]	validation_0-mae:0.222005
# [951]	validation_0-mae:0.222002
# [952]	validation_0-mae:0.221999
# [953]	validation_0-mae:0.221997
# [954]	validation_0-mae:0.221995
# [955]	validation_0-mae:0.221994
# [956]	validation_0-mae:0.221993
# [957]	validation_0-mae:0.221992
# [958]	validation_0-mae:0.221992
# [959]	validation_0-mae:0.221985
# [960]	validation_0-mae:0.221983
# [961]	validation_0-mae:0.221982
# [962]	validation_0-mae:0.22198
# [963]	validation_0-mae:0.221978
# [964]	validation_0-mae:0.221976
# [965]	validation_0-mae:0.221974
# [966]	validation_0-mae:0.221973
# [967]	validation_0-mae:0.221973
# [968]	validation_0-mae:0.221972
# [969]	validation_0-mae:0.221972
# [970]	validation_0-mae:0.221969
# [971]	validation_0-mae:0.221968
# [972]	validation_0-mae:0.221966
# [973]	validation_0-mae:0.221965
# [974]	validation_0-mae:0.221963
# [975]	validation_0-mae:0.221963
# [976]	validation_0-mae:0.221962
# [977]	validation_0-mae:0.221961
# [978]	validation_0-mae:0.221956
# [979]	validation_0-mae:0.221953
# [980]	validation_0-mae:0.221951
# [981]	validation_0-mae:0.221952
# [982]	validation_0-mae:0.221951
# [983]	validation_0-mae:0.221948
# [984]	validation_0-mae:0.221947
# [985]	validation_0-mae:0.221946
# [986]	validation_0-mae:0.221946
# [987]	validation_0-mae:0.221945
# [988]	validation_0-mae:0.221943
# [989]	validation_0-mae:0.221941
# [990]	validation_0-mae:0.221941
# [991]	validation_0-mae:0.22194
# [992]	validation_0-mae:0.221941
# [993]	validation_0-mae:0.221938
# [994]	validation_0-mae:0.221936
# [995]	validation_0-mae:0.221933
# [996]	validation_0-mae:0.221933
# [997]	validation_0-mae:0.221931
# [998]	validation_0-mae:0.221929
# [999]	validation_0-mae:0.221928
# {'colsample_bytree': 0.75, 'learning_rate': 0.01, 'min_child_weight': 3, 'n_estimators': 1000, 'subsample': 0.75, 'max_depth': 25, 'gamma': 0.3}

# %% [markdown]
# Sería conveniente explorar más combinaciones de parámetros para conseguir un ajuste aún más óptimo, pero tenemos ciertas limitaciones computacionales. Es un punto a considerar para productizar la solución.
#
# El Grid Search genera los siguientes mejores parámetros:
# * colsample_bytree: 0.75
# * learning_rate: 0.01
# * min_child_weight: 3
# * n_estimators: 1000
# * subsample: 0.75
# * max_depth: 25
# * gamma: 0.3

# %% [markdown]
# Guardamos el objeto Grid para posibles futuras operaciones.

# %%
pickle.dump(grid, open("grid.dat", "wb"))
#grid = pickle.load(open("grid.dat", "rb"))

# %% [markdown]
# ### 5. Evaluación

# %% [markdown]
# Proponemos dos métricas para evaluar el error del modelo :
#
# * Mean Absolute Error: $$MAE = \frac{1}{n} \sum_{i=1}^{n} \big|y_{real} - y_{pred}\big|$$
#
# * Mean Absolute Percentage Error: $$MAPE = \frac{1}{n} \sum_{i=1}^{n} \frac{\big|y_{real} - y_{pred}\big|}{\big|y_{real}\big|}$$
#
# donde $y_{real} \in \mathbb{R^n}$ son los valores reales, $y_{pred} \in \mathbb{R^n}$ son los valores de la predicción.
#
# Nos hemos decido por estas métricas ya que son las más naturales para medir el error. El MAE está expresado en euros, mientras que el MAPE es un porcentaje de error. El MAPE puede ser más representativo al tener distintos órdenes de magnitud en la variable de poder adquisitivo.
#
# Generamos las predicciones para su evaluación.

# %%
y_pred = grid.best_estimator_.predict(x_test)

# %%
# MAE
def eval_mae(true, pred, q=1.0) :
    y_diff = np.absolute(true - pred)
    y_diff_q=pd.Series(y_diff)
    y_diff_q = y_diff_q[y_diff_q<y_diff_q.quantile(q)]
    mae = np.mean(y_diff_q)
    print "MAE (" +str(int(q*100)) + "%): " + str(mae)
    plt.hist(y_diff_q, bins = 100)
    plt.title('MAE Distribution')
    plt.ylabel('Frequency')
    plt.xlabel('MAE')
    plt.show()
    return mae

mae_100 = eval_mae(np.exp(y_pred), np.exp(y_test))
# Out:
# MAE (100%): 3720.475519834419

# %% [markdown]
# Obtenemos un error medio de 3700 euros aproximadamente. Para ver mejor la distribución del error nos quedamos con aquellos errores que son inferior al percentil 0.95. De esta manera obtenemos un error medio de 2506 euros aproximadamente. Como podemos observar en la siguiente gráfica el 95% de los casos el error es menor a 12000 euros.

# %%
# MAE percentile 0.95
mae_95 = eval_mae(np.exp(y_pred), np.exp(y_test), q=0.95)
# Out:
# MAE (95%): 2596.5150635612476

# %% [markdown]
# Veamos ahora los resultados del MAPE y veremos como obtenemos otra interpretación de los resultados.

# %%
# MAPE
def eval_mape(true, pred, q=1.0) :
    mape = np.absolute(true - pred)/np.abs(true)
    y_diff_q=pd.Series(mape)
    y_diff_q = y_diff_q[y_diff_q<y_diff_q.quantile(q)]
    mape = np.mean(y_diff_q)
    print "MAPE (" +str(int(q*100)) + "%): " + str(mape)
    plt.hist(y_diff_q, bins = 100)
    plt.title('MAPE Distribution')
    plt.ylabel('Frequency')
    plt.xlabel('MAPE')
    plt.show()
    return mape

mape_100 = eval_mape(np.exp(y_pred), np.exp(y_test))
# Out:
# MAPE (100%): 0.23709158173184947

# %% [markdown]
# Obtenemos un error medio de aproximadamente un 23%. Es decir, la predicción es un 23% mayor o menor respecto al valor real de media. Si nos fijamos en el 95% de los mejores casos obtenemos un MAPE de 18% aproximadamente y podemos ver que el 95% el error del 12000 euros se corresponde como máximo a menos del 70% de error.

# %%
# MAPE percentile 0.95
mape_95 = eval_mape(np.exp(y_pred), np.exp(y_test), q=0.95)
# Out:
# MAPE (95%): 0.18406280402793576

# %% [markdown]
# En la siguiente gráfica podemos comprobar si nos equivocamos más a la alta o la baja. Realmente no se aprecia que el modelo se decante más hacia un lado que al otro.

# %%
#Pred minus real
y_diff = np.exp(y_pred)- np.exp(y_test)
plt.hist(y_diff, bins=1000)
plt.xlim(xmin=-10000, xmax=10000)
plt.title('Error Distribution')
plt.ylabel('Frequency')
plt.xlabel('MAE')
plt.show()

# %% [markdown]
# Analizemos ahora donde cometemos los errores, es decir relacionaremos el error con el poder adquisitivo.

# %%
# MAE vs Poder Adquisitivo
y_diff = np.abs(np.exp(y_pred)- np.exp(y_test))
plt.scatter(y_diff, np.exp(y_test))
plt.title('MAE vs Poder Adquisitivo')
plt.ylabel('Poder Adquisitivo')
plt.xlabel('MAE')
plt.show()

# %% [markdown]
# Como podemos observar a mayor error mayor es el poder adquisitivo como cabe esperar. Veamos ahora el mismo gráfico usando el MAPE.

# %%
# MAPE vs Poder Adquisitivo
mape = np.absolute(np.exp(y_test) - np.exp(y_pred))/np.abs(np.exp(y_test))
plt.scatter(mape, np.exp(y_test))
plt.title('MAPE vs Poder Adquisitivo')
plt.ylabel('Poder Adquisitivo')
plt.xlabel('MAPE')
plt.show()

# %% [markdown]
# De esta manera podemos ver que cometemos errores más importantes cuándo el valor del poder adquisitivo es pequeño. En cambio, a medida que el valor adquisitivo crece no obtenemos tantos errores grandes proporcionalmente hablando.
#
# Esta situación no nos preocupa si suponemos que la entidad bancaria usa esta predicción en función de umbrales: el modelo puede predicir un poder adquisitivo de 8000€ para un usuario que realmente tiene un poder adquisitivo de 4000€ y cometer un error del 100%, pero no es un problema si el banco propone productos financieros para clientes con un poder adquisitivo por debajo del umbral de 10000€. Esta necesidad de negocio basada en umbrales motiva la creación de un modelo de adicional de evaluación. En la función siguiente podemos establecer el umbral mínimo, umbral máximo, y el "step" o intervalo para crear umbrales en el recorrido entre mínimo y máximo. Para cada intervalo, se obtienen los clientes del conjunto de test cuyo poder adquisitivo esté en el rango, y de éstos se obtienen el subgrupo de clientes cuyo poder adquisitivo predicho también se situa en el mismo rango.

# %%
def thresholds_evaluation(y_test, y_pred, minimo, maximo, step):
    thresholds = np.arange(minimo,maximo,step)
    df_index = []
    df_acc = []
    df_test = []
    df_pred = []
    for limit in thresholds:
        # límite inferior
        if limit == thresholds[0]:
            test_indices = np.where(np.exp(y_test)<limit)[0]
            test_num = test_indices.shape[0]
            pred_num = np.where(np.exp(y_pred[test_indices])<limit)[0].shape[0]
            acc = np.round(100.*pred_num/test_num,2)
            df_index.append("< "+str(limit)+"€")
            df_acc.append(acc)
            df_test.append(test_num)
            df_pred.append(pred_num)
            
        # límite superior
        elif limit == thresholds[-1]:
            test_indices = np.where(np.exp(y_test)>limit)[0]
            test_num = test_indices.shape[0]
            pred_num = np.where(np.exp(y_pred[test_indices])>limit)[0].shape[0]
            acc = np.round(100.*pred_num/test_num,2)
            ##print np.exp(y_test[test_indices])
            #print np.exp(y_pred[test_indices])
            df_index.append("> "+str(limit)+"€")
            df_acc.append(acc)
            df_test.append(test_num)
            df_pred.append(pred_num)
        
    # límites intermedios
        else:
            test_indices = np.where((np.exp(y_test)<limit) & (np.exp(y_test)>(limit-step)))[0]
            test_num = test_indices.shape[0]
            pred_num = np.where(np.exp(y_pred[test_indices])<limit)[0].shape[0]
            acc = np.round(100.*pred_num/test_num,2)
            df_index.append(str(limit-step)+"€ - "+str(limit)+"€")
            df_acc.append(acc)
            df_test.append(test_num)
            df_pred.append(pred_num)
            
    df = pd.DataFrame(data=df_test,index=df_index, columns=["Muestras de Test"]) 
    df["Muestras de Pred correspondientes"] = df_pred
    df["Precisión por Umbral (%)"] = df_acc
    return df

# %% [markdown]
# Para tener una visión general, mostramos la distribución con un umbral mínimo de 5000€, máximo de 60000€, y los umbrales intermediarios obtenidos cada 5000€. Observamos como el modelo tiene más dificultad con los extremos, sobretodo en el extremo inferior.

# %%
thresholds_evaluation(y_test, y_pred, 5000, 60000, 5000)
# Out:
#                  Muestras de Test  Muestras de Pred correspondientes  \
# < 5000€                      2314                                 38
# 5000€ - 10000€              26108                              18437
# 10000€ - 15000€             27048                              22676
# 15000€ - 20000€             15038                              12741
# 20000€ - 25000€              8008                               6869
# 25000€ - 30000€              4918                               4327
# 30000€ - 35000€              2740                               2443
# 35000€ - 40000€              1528                               1351
# 40000€ - 45000€               878                                793
# 45000€ - 50000€               567                                514
# > 55000€                     1201                                306
#
#                  Precisión por Umbral (%)
# < 5000€                              1.64
# 5000€ - 10000€                      70.62
# 10000€ - 15000€                     83.84
# 15000€ - 20000€                     84.73
# 20000€ - 25000€                     85.78
# 25000€ - 30000€                     87.98
# 30000€ - 35000€                     89.16
# 35000€ - 40000€                     88.42
# 40000€ - 45000€                     90.32
# 45000€ - 50000€                     90.65
# > 55000€                            25.48

# %% [markdown]
# La distribución del poder adquisitivo centrada entorno a los 13000€ justifica mirar con más detalle esa zona. Reducimos el intervalo a 2000€ por lo que la precisión disminuye, y conseguimos conocer el rendimiento del modelo cuando variaciones de 2000€ no son relevantes desde el punto de visto de negocio.
#
# Podría agregarse un parámetro de tolerancia para tratar mejor los valores que se encuentran muy cerca de los umbrales.

# %%
thresholds_evaluation(y_test, y_pred, 5000, 30000, 2000)
# Out:
#                  Muestras de Test  Muestras de Pred correspondientes  \
# < 5000€                      2314                                 38
# 5000€ - 7000€               10245                               5074
# 7000€ - 9000€                8786                               4045
# 9000€ - 11000€              12799                               8510
# 11000€ - 13000€             11743                               8317
# 13000€ - 15000€              9583                               7020
# 15000€ - 17000€              7237                               5327
# 17000€ - 19000€              5571                               4211
# 19000€ - 21000€              4174                               3174
# 21000€ - 23000€              3356                               2609
# 23000€ - 25000€              2708                               2163
# 25000€ - 27000€              2270                               1833
# > 29000€                     8104                               4278
#
#                  Precisión por Umbral (%)
# < 5000€                              1.64
# 5000€ - 7000€                       49.53
# 7000€ - 9000€                       46.04
# 9000€ - 11000€                      66.49
# 11000€ - 13000€                     70.83
# 13000€ - 15000€                     73.25
# 15000€ - 17000€                     73.61
# 17000€ - 19000€                     75.59
# 19000€ - 21000€                     76.04
# 21000€ - 23000€                     77.74
# 23000€ - 25000€                     79.87
# 25000€ - 27000€                     80.75
# > 29000€                            52.79

# %% [markdown]
# ### 6. Modelo final y generación de predicciones

# %% [markdown]
# Con el objetivo de generar las predicciones definitivas de los clientes incluidos en el fichero Test.txt, entrenamos el modelo con los parámetros más adecuados, obtenidos del Grid Search anterior, sobre el conjunto completo de los datos de Train.txt.

# %%
train_filename = "Dataset_Salesforce_Predictive_Modelling_TRAIN.txt"
df = pd.read_csv(path+train_filename,low_memory=False)

#Remplazamos un valor hexadecimal en la variable categórica Socio_Demo_01 por su correspondiente decimal
#para que no de problemas de tipo de datos luego.
df["Socio_Demo_01"].replace(to_replace='0X301', value=769, inplace=True)
df["Socio_Demo_01"] = df["Socio_Demo_01"].astype(np.float64)

# NA
print df.shape
df = df.dropna().reset_index(drop = True)
print "Duplicated: "+str(np.any(df.duplicated().values))
print df.shape

# Outliers
print df.shape
df = df[df['Poder_Adquisitivo'] < np.percentile(df['Poder_Adquisitivo'], 99.9)]
print df.shape

#Creación de buckets para Socio_Demo_01
bucket_1,bucket_2,bucket_3,bucket_others = buckets(df)

#Labels con transformacion logaritmica
y = np.log(df["Poder_Adquisitivo"].values)

#Dataset principal sin labels
df = df.drop("Poder_Adquisitivo", axis = 1)

#Aplicamos las transformaciones
minmax = []
onehot = []
X, f_names, minmax1, onehot1 = transform(df,numerical,categorical,minmax,onehot,bucket_1,bucket_2,bucket_3,bucket_others)
# Out:
# (363834, 89)
# Duplicated: False
# (363224, 89)
# (363224, 89)
# (362860, 89)
# Features Numéricas: 50
# Features Categóricas sin OneHot encoding: 24
# Features Categóricas con OneHot encoding: 7
# Dataset: (362860, 81)

# %%
LR = LinearRegression()
LR.fit(X, y)
lr = pd.DataFrame(data=LR.predict(X),columns = ["lr"])
X = sp.hstack([X,lr])
print X.shape
# Out:
# (362860, 82)

# %% [markdown]
# Entrenamos el modelo final.

# %%
model = xgb.train({"max_depth": 25,
                  "learning_rate": 0.01,
                  "min_child_weight":3,
                  "gamma":0.3,
                  "subsample":0.75,
                  "colsample_bytree":0.75,
                  "seed":11},
                  xgb.DMatrix(X, label=y),1000)

# %%
# save model to file
pickle.dump(model, open("model.dat", "wb"))
#model = pickle.load(open("model.dat", "rb"))

# %% [markdown]
# Cargamos el fichero Test.txt y aplicamos las mismas transformaciones de variables aplicadas sobre el conjunto de Train, teniendo especial cuidado de utilizar la misma función de MinMaxScaler, ya entrenada y empleada en el paso justamente anterior.

# %%
test_filename = "Dataset_Salesforce_Predictive_Modelling_TEST.txt"
df_target = pd.read_csv(path+test_filename,low_memory=False)

#Remplazamos un valor hexadecimal en la variable categórica Socio_Demo_01 por su correspondiente decimal
#para que no de problemas de tipo de datos luego.
df_target["Socio_Demo_01"].replace(to_replace='0X301', value=769, inplace=True)
df_target["Socio_Demo_01"] = df_target["Socio_Demo_01"].astype(np.float64)

# Quitamos NA si aplica
print df_target.shape
df_target = df_target.dropna().reset_index(drop = True)
print "Duplicated: "+str(np.any(df_target.duplicated().values))
print df_target.shape

#Aplicamos las transformaciones
X_to_predict, trash1, trash2, trash3 = transform(df_target,numerical,categorical,minmax1,onehot1,bucket_1,bucket_2,bucket_3,bucket_others, train = False)
# Out:
# (156315, 88)
# Duplicated: False
# (156041, 88)
# Features Numéricas: 50
# Features Categóricas sin OneHot encoding: 24
# Features Categóricas con OneHot encoding: 7
# Dataset: (156041, 81)

# %% [markdown]
# Obtenemos las predicciones de la regresión linear, lo añadimos al dataset, obtenemos las predicciones del modelo final, y aplicamos una transformación exponencial.

# %%
lr_to_predict = pd.DataFrame(data=LR.predict(X_to_predict),columns = ["lr"])
X_to_predict = sp.hstack([X_to_predict,lr_to_predict])
y_pred = model.predict(xgb.DMatrix(X_to_predict))
print y_pred
y_pred = np.exp(y_pred)
print y_pred
# Out:
# [10.14494   9.581853  9.937906 ...  8.738752  9.522396  8.666217]
# [25461.947  14499.261  20700.357  ...  6240.1055 13662.309   5803.5024]

# %% [markdown]
# Exportamos el resultado a un fichero Test_Mission.txt en el formato solicitado.

# %%
result_filename = "Test_Mission.txt"

y_pred_data=pd.DataFrame(data=y_pred, columns=["PA_Est"])
customerid=pd.DataFrame(data=df_target["ID_Customer"])
output = customerid.assign(PA_Est=y_pred_data)
output.to_csv(path+result_filename,sep=",", encoding="utf-8", index=False,quoting=None)
print output.shape
# Out:
# (156041, 2)

# %% [markdown]
# ### 7. Interpretabilidad y conclusiones

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...

# %% [markdown]
# La explicabilidad de un modelo predictivo es un aspecto clave para que una entidad financiera pueda utilizarlo y ser transparente con sus clientes, más teniendo en cuenta la última reglamentación europea al respecto (GDPR).
# El proyecto SHAP (SHapley Additive exPlanations) plantea explicar la salida de cualquier modelo de Machine Learning basado en las contribuciones de las características empleadas en el modelo, basado en teoría de juegos. Puede encontrarse más información en:
# https://github.com/slundberg/shap

# %% [markdown]
# Obtenemos las contribuciones o "shap values" de cada característica a las predicciones.

# %%
shap_values = model.predict(xgb.DMatrix(X_to_predict.todense()[0:1000]), pred_contribs=True)

# %%
X_to_predict_df = pd.DataFrame(data=X_to_predict.todense()[0:1000],columns = np.append([f_names],'lr'))

# %% [markdown]
# Para una predicción individual, observamos las características que más pesan en incrementar esta predicción por encima del base value (promedio de todas las predicciones) en rojo, y las que más contribuyen a dismimuir el valor de la predicción en azul. Es interesante ver como, aunque algunas características se repiten para diferentes muestras, cada una aporta diferentes contribuciones, de forma positiva o negativa. Debe tomarse el logaritmo de los valores "base value" y "output value" en estas figuras para conseguir el poder adquisitivo en euro.

# %%
n=0
shap.force_plot(shap_values[n,:], X_to_predict_df.iloc[n,:])
# Out:
# <div id='iHFHE7ESFAPS5WM66NWB0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security.
# </div></div>
#  <script>
#    if (window.IML) IML.ReactDom.render(
#     IML.React.createElement(IML.AdditiveForceVisualizer, {"featureNames": ["Imp_Cons_01", "Imp_Cons_02", "Imp_Cons_03", "Imp_Cons_04", "Imp_Cons_05", "Imp_Cons_06", "Imp_Cons_07", "Imp_Cons_08", "Imp_Cons_09", "Imp_Cons_10", "Imp_Cons_11", "Imp_Cons_12", "Imp_Cons_13", "Imp_Cons_14", "Imp_Cons_15", "Imp_Cons_16", "Imp_Cons_17", "Imp_Sal_02", "Imp_Sal_04", "Imp_Sal_05", "Imp_Sal_06", "Imp_Sal_07", "Imp_Sal_08", "Imp_Sal_09", "Imp_Sal_10", "Imp_Sal_12", "Imp_Sal_13", "Imp_Sal_15", "Imp_Sal_16", "Imp_Sal_18", "Imp_Sal_19", "Imp_Sal_21", "Num_Oper_01", "Num_Oper_02", "Num_Oper_03", "Num_Oper_05", "Num_Oper_06", "Num_Oper_07", "Num_Oper_08", "Num_Oper_09", "Num_Oper_10", "Num_Oper_13", "Num_Oper_14", "Num_Oper_15", "Num_Oper_17", "Num_Oper_18", "Num_Oper_19", "Socio_Demo_03", "Socio_Demo_04", "Socio_Demo_05", "Ind_Prod_01", "Ind_Prod_02", "Ind_Prod_03", "Ind_Prod_04", "Ind_Prod_05", "Ind_Prod_06", "Ind_Prod_07", "Ind_Prod_08", "Ind_Prod_09", "Ind_Prod_10", "Ind_Prod_11", "Ind_Prod_12", "Ind_Prod_13", "Ind_Prod_14", "Ind_Prod_15", "Ind_Prod_16", "Ind_Prod_17", "Ind_Prod_18", "Ind_Prod_19", "Ind_Prod_20", "Ind_Prod_21", "Ind_Prod_22", "Ind_Prod_23", "Socio_Demo_02", "Ind_Prod_24_0", "Ind_Prod_24_1", "Ind_Prod_24_2", "Socio_Demo_01_0", "Socio_Demo_01_1", "Socio_Demo_01_2", "Socio_Demo_01_3", "lr"], "features": {"0": {"effect": -0.00023322000924963504, "value": 0.015830485874123695}, "1": {"effect": -0.004095092881470919, "value": 0.0}, "2": {"effect": -0.005693455226719379, "value": 0.0}, "3": {"effect": 0.0017875406192615628, "value": 0.017825783456634145}, "4": {"effect": 0.005779365077614784, "value": 0.0}, "5": {"effect": 0.0011935742804780602, "value": 0.01644183192027528}, "6": {"effect": -0.0013350937515497208, "value": 0.0}, "7": {"effect": -0.013170517981052399, "value": 0.0}, "8": {"effect": -0.010893705300986767, "value": 0.0}, "9": {"effect": -0.008789011277258396, "value": 0.0}, "10": {"effect": 0.002738532144576311, "value": 0.0}, "11": {"effect": -0.004743018187582493, "value": 0.0}, "12": {"effect": 0.010920993052423, "value": 0.0}, "13": {"effect": 0.010833759792149067, "value": 0.0}, "14": {"effect": 0.00021140737226232886, "value": 0.00134590625}, "15": {"effect": -0.02029503509402275, "value": 0.0}, "16": {"effect": 0.013435916975140572, "value": 0.0}, "17": {"effect": -0.005301418248564005, "value": 0.0}, "18": {"effect": -0.00021370145259425044, "value": 2.0009710855604731e-07}, "19": {"effect": 0.0028758561238646507, "value": 5.016055202452664e-06}, "20": {"effect": 0.0005182992317713797, "value": 0.0}, "21": {"effect": 0.02622579038143158, "value": 0.0}, "22": {"effect": 0.017307905480265617, "value": 0.00203801903132517}, "23": {"effect": -0.03671649470925331, "value": 0.0009399847185160134}, "24": {"effect": 0.024832215160131454, "value": 0.0002683032288784655}, "25": {"effect": -0.030797477811574936, "value": 0.0}, "26": {"effect": -0.02987087517976761, "value": 0.0}, "27": {"effect": 0.0022986619733273983, "value": 0.0}, "28": {"effect": 0.00538681959733367, "value": 0.0}, "29": {"effect": -0.00578661635518074, "value": 0.0}, "30": {"effect": 0.061990078538656235, "value": 0.07756455310306493}, "31": {"effect": 0.36108526587486267, "value": 0.06038320384491689}, "32": {"effect": 0.0003506241482682526, "value": 0.0}, "33": {"effect": -0.001541921985335648, "value": 0.0}, "34": {"effect": 0.0009994852589443326, "value": 0.0}, "35": {"effect": 0.0013877884484827518, "value": 0.019801980198019802}, "36": {"effect": 0.1038111224770546, "value": 0.006622516556291391}, "37": {"effect": 0.0017737984890118241, "value": 0.0}, "38": {"effect": -0.000633290852420032, "value": 0.0}, "39": {"effect": -0.0014403994427993894, "value": 0.0}, "40": {"effect": -0.0014429653529077768, "value": 0.0}, "41": {"effect": -0.033838748931884766, "value": 0.0}, "42": {"effect": -0.002800117013975978, "value": 0.0}, "43": {"effect": 0.016255512833595276, "value": 0.0}, "44": {"effect": -0.0004552902828436345, "value": 0.009139375476009 ...
#     document.getElementById('iHFHE7ESFAPS5WM66NWB0')
#   );
# </script>

# %%
n=6
shap.force_plot(shap_values[n,:], X_to_predict_df.iloc[n,:])
# Out:
# <div id='iCNB7CAUVY8OJ9B4BHVSG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security.
# </div></div>
#  <script>
#    if (window.IML) IML.ReactDom.render(
#     IML.React.createElement(IML.AdditiveForceVisualizer, {"featureNames": ["Imp_Cons_01", "Imp_Cons_02", "Imp_Cons_03", "Imp_Cons_04", "Imp_Cons_05", "Imp_Cons_06", "Imp_Cons_07", "Imp_Cons_08", "Imp_Cons_09", "Imp_Cons_10", "Imp_Cons_11", "Imp_Cons_12", "Imp_Cons_13", "Imp_Cons_14", "Imp_Cons_15", "Imp_Cons_16", "Imp_Cons_17", "Imp_Sal_02", "Imp_Sal_04", "Imp_Sal_05", "Imp_Sal_06", "Imp_Sal_07", "Imp_Sal_08", "Imp_Sal_09", "Imp_Sal_10", "Imp_Sal_12", "Imp_Sal_13", "Imp_Sal_15", "Imp_Sal_16", "Imp_Sal_18", "Imp_Sal_19", "Imp_Sal_21", "Num_Oper_01", "Num_Oper_02", "Num_Oper_03", "Num_Oper_05", "Num_Oper_06", "Num_Oper_07", "Num_Oper_08", "Num_Oper_09", "Num_Oper_10", "Num_Oper_13", "Num_Oper_14", "Num_Oper_15", "Num_Oper_17", "Num_Oper_18", "Num_Oper_19", "Socio_Demo_03", "Socio_Demo_04", "Socio_Demo_05", "Ind_Prod_01", "Ind_Prod_02", "Ind_Prod_03", "Ind_Prod_04", "Ind_Prod_05", "Ind_Prod_06", "Ind_Prod_07", "Ind_Prod_08", "Ind_Prod_09", "Ind_Prod_10", "Ind_Prod_11", "Ind_Prod_12", "Ind_Prod_13", "Ind_Prod_14", "Ind_Prod_15", "Ind_Prod_16", "Ind_Prod_17", "Ind_Prod_18", "Ind_Prod_19", "Ind_Prod_20", "Ind_Prod_21", "Ind_Prod_22", "Ind_Prod_23", "Socio_Demo_02", "Ind_Prod_24_0", "Ind_Prod_24_1", "Ind_Prod_24_2", "Socio_Demo_01_0", "Socio_Demo_01_1", "Socio_Demo_01_2", "Socio_Demo_01_3", "lr"], "features": {"0": {"effect": -6.548207602463663e-05, "value": 0.007978610008443006}, "1": {"effect": -0.00476427748799324, "value": 0.0}, "2": {"effect": -0.02097754180431366, "value": 0.0}, "3": {"effect": -0.0053580328822135925, "value": 0.0082523809203925}, "4": {"effect": 0.012824716046452522, "value": 0.0}, "5": {"effect": 0.005075626540929079, "value": 0.017947911317850642}, "6": {"effect": 0.0007374094566330314, "value": 0.0}, "7": {"effect": -0.013993430882692337, "value": 0.0}, "8": {"effect": -0.009376930072903633, "value": 0.0}, "9": {"effect": -0.008887474425137043, "value": 0.0}, "10": {"effect": -0.0013008681125938892, "value": 0.0059485152532474245}, "11": {"effect": -0.0012829032493755221, "value": 0.018439365545487918}, "12": {"effect": 0.008274870924651623, "value": 0.0}, "13": {"effect": 0.03172954544425011, "value": 0.0}, "14": {"effect": 0.004482909571379423, "value": 0.0025514687500000004}, "15": {"effect": -0.018029525876045227, "value": 0.0}, "16": {"effect": 0.00546671636402607, "value": 0.0}, "17": {"effect": -0.00227950606495142, "value": 3.3178457454793175e-05}, "18": {"effect": -0.0011247828369960189, "value": 2.0009710855604731e-07}, "19": {"effect": 0.0020800114143639803, "value": 5.016055202452664e-06}, "20": {"effect": -0.0027014706283807755, "value": 0.0}, "21": {"effect": 0.041114453226327896, "value": 0.0}, "22": {"effect": -0.051696453243494034, "value": 0.0003780288361509842}, "23": {"effect": -0.2665986120700836, "value": 0.00039012947317052676}, "24": {"effect": 0.00707176374271512, "value": 8.211469205459361e-05}, "25": {"effect": -0.03415200114250183, "value": 0.0}, "26": {"effect": -0.03150968253612518, "value": 0.0}, "27": {"effect": 0.006756559945642948, "value": 0.0}, "28": {"effect": 0.016755802556872368, "value": 0.0}, "29": {"effect": -0.007501926738768816, "value": 0.0}, "30": {"effect": 0.016751982271671295, "value": 0.011298905546292648}, "31": {"effect": 0.10084165632724762, "value": 0.00920764692138084}, "32": {"effect": 0.0018164421198889613, "value": 0.0021551724137931034}, "33": {"effect": -0.0002990376960951835, "value": 0.0}, "34": {"effect": 0.0026418836787343025, "value": 0.0}, "35": {"effect": 0.014673911035060883, "value": 0.006600660066006601}, "36": {"effect": 0.036585815250873566, "value": 0.006622516556291391}, "37": {"effect": -0.0022719032131135464, "value": 0.0}, "38": {"effect": -0.000870110874529928, "value": 0.0}, "39": {"effect": -0.003653522813692689, "value": 0.0}, "40": {"effect": -0.0016114850295707583, "value": 0.0}, "41": {"effect": -0.033469170331954956, "value": 0.0}, "42": {"effect": -0.012547631748020649, "value": 0.0}, "43": {"effect": 0.035958584398031235, ...
#     document.getElementById('iCNB7CAUVY8OJ9B4BHVSG')
#   );
# </script>

# %% [markdown]
# Para tener una idea genérica de la importancia de las características, mostramos la distribución del impacto que aporta cada caracterítica en la salida del modelo para cada feature, ordenadas por importancia. A mayor importes de los saldos (por ejemplo "Imp_Sal_21"), mayor es la contribución a aumentar el poder adquisitivo. La variable creada de la regresión lineal está entre las más relevantes, al igual que algunos saldos, consumos, y la variable Socio_Demo_03 que muy probablemente sea la edad (por su distribución).

# %%
shap.summary_plot(shap_values, X_to_predict_df)

# %% [markdown]
# A lo largo de este proyecto hemos realizado una exploración exhaustiva de los datos, que ha justificado una serie de transformaciones y creaciones de nuevas variables, como por ejemplo aplicar el logaritmo al Poder Adquisitivo. Tras probar varios modelos predictivos, aplicamos un modelo de ensamblado de árboles de decisión para regresión, XGBoost, que evaluamos mediante Mean Absolute Error y Mean Absolute Percentage Error principalmente. Entrenamos un modelo final sobre el conjunto completo de train y generamos las predicciones de Poder Adquisitivo sobre el conjunto de test, adjuntas a este documento. Mostramos finalmente las métricas obtenidas.

# %%
results = pd.DataFrame(data = [mae_100, mae_95, mape_100, mape_95], index = ["MAE (100%)","MAE (95%)","MAPE (100%)","MAPE (95%)"], columns = ["Evaluation Table"])
results
# Out:
#              Evaluation Table
# MAE (100%)        3720.475520
# MAE (95%)         2596.515064
# MAPE (100%)          0.237092
# MAPE (95%)           0.184063
